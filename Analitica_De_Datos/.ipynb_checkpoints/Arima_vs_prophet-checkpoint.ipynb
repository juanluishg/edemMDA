# %% [markdown]
# Arima

# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.0-cp38-cp38-win_amd64.whl (616 kB)
# Collecting Cython<0.29.18,>=0.29
#   Downloading Cython-0.29.17-cp38-cp38-win_amd64.whl (1.7 MB)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from pmdarima) (0.24.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from pmdarima) (1.6.1)
# Requirement already satisfied: urllib3 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from pmdarima) (1.26.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: pandas>=0.19 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from pmdarima) (0.12.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from pmdarima) (49.2.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.19->pmdarima) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.1.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Installing collected packages: Cython, pmdarima
# Successfully installed Cython-0.29.17 pmdarima-1.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing required Libraries
import numpy as np
import pandas as pd
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf 
from statsmodels.tsa.seasonal import seasonal_decompose 
from pmdarima import auto_arima                        
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse
import warnings
warnings.filterwarnings("ignore")

# %%
#Read the dataset
df = pd.read_csv('datasets/datasets_56102_107707_monthly-beer-production-in-austr.csv')
df.head()
# Out:
#      Month  Monthly beer production
# 0  1956-01                     93.2
# 1  1956-02                     96.0
# 2  1956-03                     95.2
# 3  1956-04                     77.1
# 4  1956-05                     70.9

# %%
df.shape
# Out:
# (476, 2)

# %%
df.tail (15)
# Out:
#        Month  Monthly beer production
# 461  1994-06                    125.0
# 462  1994-07                    127.0
# 463  1994-08                    143.0
# 464  1994-09                    143.0
# 465  1994-10                    160.0
# 466  1994-11                    190.0
# 467  1994-12                    182.0
# 468  1995-01                    138.0
# 469  1995-02                    136.0
# 470  1995-03                    152.0
# 471  1995-04                    127.0
# 472  1995-05                    151.0
# 473  1995-06                    130.0
# 474  1995-07                    119.0
# 475  1995-08                    153.0

# %%
df.Month = pd.to_datetime(df.Month)
df = df.set_index("Month")
df.head()
# Out:
#             Monthly beer production
# Month
# 1956-01-01                     93.2
# 1956-02-01                     96.0
# 1956-03-01                     95.2
# 1956-04-01                     77.1
# 1956-05-01                     70.9

# %%
df.rename(columns={'Monthly beer production': 'Monthly_Prod'}, inplace=True)

# %%
df.head
# Out:
# <bound method NDFrame.head of             Monthly_Prod
# Month
# 1956-01-01          93.2
# 1956-02-01          96.0
# 1956-03-01          95.2
# 1956-04-01          77.1
# 1956-05-01          70.9
# ...                  ...
# 1995-04-01         127.0
# 1995-05-01         151.0
# 1995-06-01         130.0
# 1995-07-01         119.0
# 1995-08-01         153.0
#
# [476 rows x 1 columns]>

# %%
#Basic Data Plot
df.index.freq = 'MS' #month start
ax = df['Monthly_Prod'].plot(figsize = (16,5), title = "Monthly Beer Production")
ax.set(xlabel='Dates', ylabel='Total Production');

# %%
#Seasonal Decompose Plots
a = seasonal_decompose(df["Monthly_Prod"], model = "add")
a.plot();

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (20,7))
a.seasonal.plot();

# %% [markdown]
# The parameters of the ARIMA model are defined as follows:
#
# p: The number of lag observations included in the model, also called the lag order.
#
# ---
#
#
# d: The number of times that the raw observations are differenced, also called the degree of differencing.
#
# ---
#
#
# q: The size of the moving average window, also called the order of moving average.

# %%
#ARIMA Forecast
#Finding the best values for p,q,d,P,Q,D

auto_arima(df['Monthly_Prod'], seasonal=True, m=12,max_p=7, max_d=5,max_q=7, max_P=4, max_D=4,max_Q=4).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  476
# Model:             SARIMAX(5, 1, 4)x(1, 0, [1], 12)   Log Likelihood               -1724.199
# Date:                              Wed, 24 Feb 2021   AIC                           3472.398
# Time:                                      15:40:11   BIC                           3522.358
# Sample:                                           0   HQIC                          3492.045
#                                               - 476
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2142      0.054     -3.970      0.000      -0.320      -0.108
# ar.L2         -0.0976      0.058     -1.681      0.093      -0.211       0.016
# ar.L3          0.7315      0.055     13.201      0.000       0.623       0.840
# ar.L4         -0.1624      0.049     -3.327      0.001      -0.258      -0.067
# ar.L5          0.0130      0.049      0.269      0.788      -0.082       0.108
# ma.L1         -0.7497      0.035    -21.658      0.000      -0.818      -0.682
# ma.L2         -0.1650      0.027     -6.074      0.000      -0.218      -0.112
# ma.L3         -0.7948      0.026    -30.682      0.000      -0.846      -0.744
# ma.L4          0.8586      0.031     27.885      0.000       0.798       0.919
# ar.S.L12       0.9943      0.005    217.279      0.000       0.985       1.003
# ma.S.L12      -0.8146      0.037    -21.910      0.000      -0.887      -0.742
# sigma2        78.4266      4.196     18.689      0.000      70.202      86.651
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.16   Jarque-Bera (JB):                70.85
# Prob(Q):                              0.69   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.94   Skew:                            -0.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#Train-Test split

train_data = df[:len(df)-12] 
test_data = df[len(df)-12:] #last 12 months
arima_model = SARIMAX(train_data['Monthly_Prod'], order = (2,1,1), seasonal_order = (4,0,3,12))
arima_result = arima_model.fit()
arima_result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                          SARIMAX Results
# ==================================================================================================
# Dep. Variable:                               Monthly_Prod   No. Observations:                  464
# Model:             SARIMAX(2, 1, 1)x(4, 0, [1, 2, 3], 12)   Log Likelihood               -1707.969
# Date:                                    Wed, 24 Feb 2021   AIC                           3437.938
# Time:                                            15:52:25   BIC                           3483.453
# Sample:                                        01-01-1956   HQIC                          3455.856
#                                              - 08-01-1994
# Covariance Type:                                      opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1172      0.035     -3.345      0.001      -0.186      -0.049
# ar.L2         -0.1673      0.047     -3.576      0.000      -0.259      -0.076
# ma.L1         -0.8457      0.027    -30.847      0.000      -0.899      -0.792
# ar.S.L12       1.7576      0.121     14.544      0.000       1.521       1.995
# ar.S.L24      -1.6137      0.233     -6.931      0.000      -2.070      -1.157
# ar.S.L36       0.7935      0.184      4.306      0.000       0.432       1.155
# ar.S.L48       0.0612      0.067      0.909      0.364      -0.071       0.193
# ma.S.L12      -1.5565      0.130    -11.973      0.000      -1.811      -1.302
# ma.S.L24       1.3902      0.216      6.437      0.000       0.967       1.814
# ma.S.L36      -0.6637      0.125     -5.306      0.000      -0.909      -0.419
# sigma2        85.1704      4.979     17.106      0.000      75.412      94.929
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                40.57
# Prob(Q):                              0.81   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.06   Skew:                            -0.30
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#Prediction
arima_pred = arima_result.predict(start = len(train_data), end = len(df)-1, typ="levels").rename("ARIMA Predictions") #last 12 months
arima_pred
# Out:
# 1994-09-01    134.241516
# 1994-10-01    157.620190
# 1994-11-01    181.593237
# 1994-12-01    183.646905
# 1995-01-01    145.052873
# 1995-02-01    137.066758
# 1995-03-01    151.360742
# 1995-04-01    133.289272
# 1995-05-01    137.980286
# 1995-06-01    120.671092
# 1995-07-01    128.454060
# 1995-08-01    138.979393
# Freq: MS, Name: ARIMA Predictions, dtype: float64

# %%
test_data['Monthly_Prod'].plot(figsize = (16,5), legend=True)
arima_pred.plot(legend = True);

# %%
#Model Evaluation
arima_rmse_error = rmse(test_data['Monthly_Prod'], arima_pred)
arima_mse_error = arima_rmse_error**2
mean_value = df['Monthly_Prod'].mean()

print(f'MSE Error: {arima_mse_error}\nRMSE Error: {arima_rmse_error}\nMean: {mean_value}')
# Out:
# MSE Error: 65.75860371663133
# RMSE Error: 8.109167880654052
# Mean: 136.39537815126045

# %%
test_data['ARIMA_Predictions'] = arima_pred

# %% [markdown]
# Prophet

# %%
df_pr = df.copy()
df_pr = df.reset_index()
df_pr.columns = ['ds','y'] # To use prophet column names should be like that
train_data_pr = df_pr.iloc[:len(df)-12]
test_data_pr = df_pr.iloc[len(df)-12:]

# %%
from fbprophet import Prophet
m = Prophet()
m.fit(train_data_pr)
future = m.make_future_dataframe(periods=12,freq='MS')
prophet_pred = m.predict(future)
prophet_pred.tail()
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds       trend  ...  multiplicative_terms_upper        yhat
# 471 1995-04-01  151.043859  ...                         0.0  143.086155
# 472 1995-05-01  150.979616  ...                         0.0  139.585118
# 473 1995-06-01  150.913231  ...                         0.0  127.008661
# 474 1995-07-01  150.848988  ...                         0.0  135.097374
# 475 1995-08-01  150.782603  ...                         0.0  141.573101
#
# [5 rows x 16 columns]

# %%
prophet_pred = pd.DataFrame({"Date" : prophet_pred[-12:]['ds'], "Pred" : prophet_pred[-12:]["yhat"]})
prophet_pred = prophet_pred.set_index("Date")
prophet_pred.index.freq = "MS"
prophet_pred
# Out:
#                   Pred
# Date
# 1994-09-01  144.980217
# 1994-10-01  166.012222
# 1994-11-01  173.629620
# 1994-12-01  185.881744
# 1995-01-01  155.163406
# 1995-02-01  146.732442
# 1995-03-01  158.844417
# 1995-04-01  143.086155
# 1995-05-01  139.585118
# 1995-06-01  127.008661
# 1995-07-01  135.097374
# 1995-08-01  141.573101

# %%
test_data["Prophet_Predictions"] = prophet_pred['Pred'].values
import seaborn as sns
plt.figure(figsize=(16,5))
ax = sns.lineplot(x= test_data.index,label='Monthly_Prod', y=test_data["Monthly_Prod"])
sns.lineplot(x=test_data.index, label='Prophet_Predictions', y = test_data["Prophet_Predictions"]);

# %%
prophet_rmse_error = rmse(test_data['Monthly_Prod'], test_data["Prophet_Predictions"])
prophet_mse_error = prophet_rmse_error**2
mean_value = df['Monthly_Prod'].mean()

print(f'MSE Error: {prophet_mse_error}\nRMSE Error: {prophet_rmse_error}\nMean: {mean_value}')
# Out:
# MSE Error: 130.62088996007174
# RMSE Error: 11.428949643780557
# Mean: 136.39537815126045

# %%
#Comparison

rmse_errors = [arima_rmse_error, prophet_rmse_error]
mse_errors = [arima_mse_error, prophet_mse_error]
errors = pd.DataFrame({"Models" : ["ARIMA", "Prophet"],"RMSE Errors" : rmse_errors, "MSE Errors" : mse_errors})
plt.figure(figsize=(16,9))
plt.plot_date(test_data.index, label='Monthly_Prod', y=test_data["Monthly_Prod"], linestyle="-")
plt.plot_date(test_data.index, label='ARIMA_Predictions', y=test_data["ARIMA_Predictions"], linestyle="-.")
plt.plot_date(test_data.index, label='Prophet_Predictions', y=test_data["Prophet_Predictions"], linestyle=":")
plt.legend()
plt.show()

# %%
print(f"Mean: {test_data['Monthly_Prod'].mean()}")
errors
# Out:
# Mean: 148.41666666666666
#     Models  RMSE Errors  MSE Errors
# 0    ARIMA     8.109168   65.758604
# 1  Prophet    11.428950  130.620890

# %%
#Final Prediction data
test_data
# Out:
#             Monthly_Prod  ARIMA_Predictions  Prophet_Predictions
# Month
# 1994-09-01         143.0         134.241516           144.980217
# 1994-10-01         160.0         157.620190           166.012222
# 1994-11-01         190.0         181.593237           173.629620
# 1994-12-01         182.0         183.646905           185.881744
# 1995-01-01         138.0         145.052873           155.163406
# 1995-02-01         136.0         137.066758           146.732442
# 1995-03-01         152.0         151.360742           158.844417
# 1995-04-01         127.0         133.289272           143.086155
# 1995-05-01         151.0         137.980286           139.585118
# 1995-06-01         130.0         120.671092           127.008661
# 1995-07-01         119.0         128.454060           135.097374
# 1995-08-01         153.0         138.979393           141.573101
