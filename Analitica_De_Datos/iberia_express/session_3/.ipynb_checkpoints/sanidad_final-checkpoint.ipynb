# %% [markdown]
# # Predicción de Exitus (fallecimiento). Comparativa final

# %%
# Load Libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd 
import multiprocessing
import random
from sklearn.metrics import roc_auc_score as metric




from sklearn.preprocessing import scale
from sklearn.preprocessing import OneHotEncoder
import timeit

# %% [markdown]
# ## Dataset

# %% [markdown]
# Leamos el dataset a utilizar.

# %%
# Load the dataset 
X = pd.read_csv("./datasets/dat_sanidad.csv", sep=';', decimal=',', encoding='latin-1')
X.shape
# Out:
# (32706, 10)

# %% [markdown]
# El dataset consta de:
#
# - 32706 **filas** o instancias
# - 10 **columnas** o variables.
#
# Veamos su contenido.

# %%
X.head()
# Out:
#    gravedad  pct_mortalidad_norma  edad_dias  numproc  potencial_ambul  proc  \
# 0         4              0.408730      12596       21                0     1
# 1         4              0.306931      20973       22                0     1
# 2         4              0.278481      19611       19                0     1
# 3         3              0.150289      13583       22                0     1
# 4         1              0.016573      18042        2                0     1
#
#    estancia_esperada tipgrd  tiping  exitus
# 0                151      Q       1       0
# 1                 99      Q       1       0
# 2                 87      Q       1       0
# 3                100      Q       1       0
# 4                 44      Q       1       0

# %% [markdown]
# - **gravedad**: Gravedad dentro del GRD. Valores de 1 a 4.
#
# - **pct_mortalidad_norma**: Tasa de mortalidad histórica para ese GRD.
#
# - **edad_dias**: Edad en días del paciente.
#
# - **numproc**: Número de procedimientos que se han llevado a cabo al paciente a las 24 horas.
#
# - **potencial_ambul**: Flag (valor 0 = no / 1 = sí) que indica si el caso se ha catalogado como potencialmente ambulatorio, es decir, no requiere ingreso.
#
# - **proc**: Procedencia del paciente.
#
# - **estancia_esperada**: Número de días que se espera que el paciente esté ingresado en el hospital por este episodio asistencial.
#
# - **tipgrd**: GRD médico (M) o de quirófano (Q).
#
# - **tiping**: Tipo de ingreso: Programado, urgente...
#
# - **exitus**: 1 = El paciente falleció.
#
# De estas variables, fecing la usaremos para realizar el split en train/validacion/test, exitus es el target y las 10 variables restantes serán el input de nuestro modelo.

# %% [markdown]
# ## Pre-procesado

# %% [markdown]
# ### One-Hot Encoding

# %% [markdown]
# Utilizaremos la técnica de one-hot encoding.
#
# <img src="../figures/oh.png" width="50%">

# %% [markdown]
# Seleccionemos las variables categóricas en primer lugar.

# %%
categorical_vars = set(['gravedad', 'proc', 'tiping', 'tipgrd'])
numerical_vars = set(X.columns) - categorical_vars
categorical_vars = list(categorical_vars)
numerical_vars = list(numerical_vars)

# %%
print(categorical_vars)
print(numerical_vars)
# Out:
# ['tipgrd', 'tiping', 'gravedad', 'proc']
# ['exitus', 'estancia_esperada', 'potencial_ambul', 'edad_dias', 'pct_mortalidad_norma', 'numproc']

# %% [markdown]
# Realizamos one hot encoding de las variables categoricas

# %%
ohe = OneHotEncoder(sparse = False)
ohe_fit = ohe.fit(X[categorical_vars])
X_ohe = pd.DataFrame(ohe.fit_transform(X[categorical_vars]))
X_ohe.columns = pd.DataFrame(ohe_fit.get_feature_names())

# %% [markdown]
# Volvemos a pegar las variables numéricas.

# %%
X = pd.concat((X_ohe, X[numerical_vars].reset_index()), axis=1)
del X['index']

# %% [markdown]
# ### Tipificar

# %% [markdown]
# Ahora vamos a tipificar los datos, es decir, llevarlos a media 0 y desviación estándar 1.

# %% [markdown]
# <img src="../figures/tipify.png" width="50%">

# %%
y = X['exitus']
del X['exitus']

# %%
X_scale = pd.DataFrame(scale(X))
X_scale.columns = X.columns
X = X_scale
X.columns = X_scale.columns
print(X.head())
# Out:
#     (x0_M,)   (x0_Q,)   (x1_1,)  (x1_2,)   (x1_3,)   (x2_1,)   (x2_2,)  \
# 0 -1.554964  1.554964  0.589285  -0.5681 -0.118114 -1.322185 -0.435743
# 1 -1.554964  1.554964  0.589285  -0.5681 -0.118114 -1.322185 -0.435743
# 2 -1.554964  1.554964  0.589285  -0.5681 -0.118114 -1.322185 -0.435743
# 3 -1.554964  1.554964  0.589285  -0.5681 -0.118114 -1.322185 -0.435743
# 4 -1.554964  1.554964  0.589285  -0.5681 -0.118114  0.756324 -0.435743
#
#     (x2_3,)   (x2_4,)   (x3_1,)  ...   (x3_4,)   (x3_6,)   (x3_7,)   (x3_8,)  \
# 0 -0.417921  4.120705  0.589002  ... -0.140259 -0.118114 -0.009578 -0.134718
# 1 -0.417921  4.120705  0.589002  ... -0.140259 -0.118114 -0.009578 -0.134718
# 2 -0.417921  4.120705  0.589002  ... -0.140259 -0.118114 -0.009578 -0.134718
# 3  2.392797 -0.242677  0.589002  ... -0.140259 -0.118114 -0.009578 -0.134718
# 4 -0.417921 -0.242677  0.589002  ... -0.140259 -0.118114 -0.009578 -0.134718
#
#     (x3_9,)  estancia_esperada  potencial_ambul  edad_dias  \
# 0 -0.090724          19.632898        -0.258527  -0.713484
# 1 -0.090724          12.641211        -0.258527   0.186170
# 2 -0.090724          11.027745        -0.258527   0.039897
# 3 -0.090724          12.775667        -0.258527  -0.607484
# 4 -0.090724           5.246158        -0.258527  -0.128607
#
#    pct_mortalidad_norma   numproc
# 0              5.678791  6.002393
# 1              4.151382  6.357038
# 2              3.724521  5.293102
# 3              1.801116  6.357038
# 4             -0.205167 -0.735868
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Split en Train/Validación/Test

# %% [markdown]
# Utilizaremos a modo de ejemplo los ratios habitualmente recomendados:
#
# • Train: 70%.
#
# • Validación: 15%.
#
# • Test: 15%.

# %%
perc_values = [0.7, 0.15, 0.15];

# %% [markdown]
# Creamos los conjuntos de train, validacion y test con el tamaño seleccionado pero respetando el eje temporal.

# %%
# dimensiones de los conjuntos de train y test
n_train = int(X.shape[0] * perc_values[0])
n_val = int(X.shape[0] * perc_values[1])
n_test = int(X.shape[0] * perc_values[2])

# selección del conjunto de train
X_train = X.iloc[:n_train]
y_train = y.iloc[:n_train]

# selección del conjunto de validación
X_val = X.iloc[(n_train):(n_train+n_val)]
y_val = y.iloc[(n_train):(n_train+n_val)]

# selección del conjunto de test
X_test = X.iloc[(n_train+n_val):]
y_test = y.iloc[(n_train+n_val):]

# %% [markdown]
# Visualizamos el tamaño de los 3 subdatasets

# %%
print('Train data size = ' + str(X_train.shape))
print('Train target size = ' + str(y_train.shape))
print('Validation data size = ' + str(X_val.shape))
print('Validation target size = ' + str(y_val.shape))
print('Test data size = ' + str(X_test.shape))
print('Test target size = ' + str(y_test.shape))
# Out:
# Train data size = (22894, 22)
# Train target size = (22894,)
# Validation data size = (4905, 22)
# Validation target size = (4905,)
# Test data size = (4907, 22)
# Test target size = (4907,)

# %% [markdown]
# # Grid Search

# %% [markdown]
# Vamos a proceder a realizar un grid search que compare todos los modelos de clasificación que hemos visto, es decir:
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Importamos todos los modelos que vamos a usar.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %% [markdown]
# Importamos la métrica, en este caso AUC.

# %%
from sklearn.metrics import roc_auc_score as metric;

# %% [markdown]
# Definimos algunos parámetros generales.

# %%
random_state = 1;
nthread = multiprocessing.cpu_count() - 1;
scale_pos_weight = sum(y_train == 0) / sum(y_train == 1);

# %% [markdown]
# Vamos a calcular los puntos recomendados por Cherkassky para la SVM.

# %%
n = X_train.shape[0];
d = X_train.shape[1];
m = np.mean(y_train);
s = np.std(y_train);
C_cherk = np.max([np.abs(m + 3*s),np.abs(m - 3*s)]);
gamma_cherk = np.power(0.2, 1/d)

# %% [markdown]
# Definimos el grid a llevar a cabo

# %%
# Regresion Logística
regularization_values = ['l1', 'l2', 'none'];
penalty_values = [1, 10, 100];

# SVM
C_values = [C_cherk, 5e-03, 4.5e-03, 4e-03];
gamma_kernel_values = [gamma_cherk, 3.26e-09, 3.255e-09, 3.25e-09];

# Arbol de Decision
max_depth_values = [None, 6, 20];
min_samples_split_values = [2, 5, 20];
min_samples_leaf_values = [1, 5, 20];
max_features_values = [None, 1, 2];

# Random Forest
ntrees_values = [10, 100, 1000];

# Xgboost
nrounds_values = [10, 100]
eta_values = [0.3, 0.99]
gamma_values = [0, 1]
max_depth_values = [6, 20]
min_child_weight_values = [1, 20]
subsample_values = [0.1, 1]
colsample_bytree_values = [0.1, 1]
num_parallel_tree_values = [1, 20]
lambda_values = [0, 1]
alpha_values = [0, 1]

# %%
params_values = [{'model': 'logistic regression',
                  'regularization': regularization_values,
                 'penalty': penalty_values},
                 {'model': 'svm',
                  'C': C_values,
                 'gamma_kernel': gamma_kernel_values},
                 {'model': 'decision tree',
                 'max_depth': max_depth_values,
                 'min_samples_split': min_samples_split_values,
                 'min_samples_leaf': min_samples_leaf_values,
                 'max_features': max_features_values},
                 {'model': 'random forest',
                  'n_trees': ntrees_values,
                 'max_depth': max_depth_values,
                 'min_samples_split': min_samples_split_values,
                 'min_samples_leaf': min_samples_leaf_values,
                 'max_features': max_features_values},
                 {'model': 'xgboost',
                  'nrounds': nrounds_values,
                  'eta': eta_values,
                 'gamma': gamma_values,
                 'max_depth': max_depth_values,
                 'min_child_weight': min_child_weight_values,
                 'subsample': subsample_values,
                 'colsample_bytree': colsample_bytree_values,
                 'num_parallel_tree': num_parallel_tree_values,
                 'lambda': lambda_values,
                 'alpha': alpha_values}]

# %%
total_iteraciones = 0
for params in params_values:
    if params['model'] == 'logistic regression':
        n = len(params['regularization'])*len(params['penalty'])
    elif params['model'] == 'svm':
        n = len(params['C'])*len(params['gamma_kernel'])
    elif params['model'] == 'decision tree':
        n = len(params['max_depth'])*len(params['min_samples_split'])*len(params['min_samples_leaf'])*len(params['max_features'])
    elif params['model'] == 'random forest':
        n = len(params['n_trees'])*len(params['max_depth'])*len(params['min_samples_split'])*len(params['min_samples_leaf'])*len(params['max_features'])
    elif params['model'] == 'xgboost':
        n = len(params['nrounds'])*len(params['eta'])*len(params['gamma'])*len(params['max_depth'])*len(params['min_child_weight'])*len(params['subsample'])*len(params['colsample_bytree'])*len(params['num_parallel_tree'])*len(params['lambda'])*len(params['alpha'])
    total_iteraciones = total_iteraciones + n;
    print(str(n)+ ' iteraciones de ' + str(params['model']))
print(str(total_iteraciones)+ ' iteraciones en total')
# Out:
# 9 iteraciones de logistic regression
# 16 iteraciones de svm
# 54 iteraciones de decision tree
# 162 iteraciones de random forest
# 1024 iteraciones de xgboost
# 1265 iteraciones en total

# %%
grid_results = pd.DataFrame();
num_iter = 0
for params in params_values:
    
    # Logistic Regression
    if params['model'] == 'logistic regression':
        for regularization in params['regularization']:
            for penalty in params['penalty']:  
                
                # Actualizar contador
                num_iter += 1; 
                
                # print control iteracion modelo
                print('Inicio de iteracion ' + str(num_iter) + 
                      '. Regularizacion = ' + str(regularization) + 
                      ', Lambda = '  + str(penalty) +
                      '\n')
                
                # Entrenar modelo
                if regularization == 'l1':
                    model = LogisticRegression(penalty = regularization, solver = 'liblinear', C = penalty, random_state = random_state)
                else:
                    model = LogisticRegression(penalty = regularization,solver = 'lbfgs', C = penalty, random_state = random_state)
               
                model.fit(X_train, np.array(y_train))

                # Generar predicciones
                pred_train_p = model.predict_proba(X_train)
                pred_val_p = model.predict_proba(X_val)

                # Calcular métricas de evaluación
                auc_train = metric(y_train, pred_train_p[:, 1])
                auc_val = metric(y_val, pred_val_p[:, 1])                                            

                print('Fin de iteracion ' + str(num_iter) + 
                     '. Regularizacion = ' + str(regularization) + 
                      ', Lambda = '  + str(penalty) +
                      '. AUC train = '  + str(auc_train) + 
                      ' -  AUC val = '  + str(auc_val)  + 
                      '\n')
                grid_results = grid_results.append(pd.DataFrame(data={'model':'Logistic Regression',
                                                                      'params': [{'regularization':[regularization],
                                                                                  'penalty':[penalty]}],
                                                                      'auc_train':[auc_train],
                                                                      'auc_val':[auc_val]},
                                                               columns=['model','params', 'auc_train', 'auc_val']), 
                                                   ignore_index=True)
                
     
    # SVM
    if params['model'] == 'svm':
        for C in params['C']:
            for gamma_kernel in params['gamma_kernel']:  
                
                # Actualizar contador
                num_iter += 1; 
                
                # print control iteracion modelo
                print('Inicio de iteracion ' + str(num_iter) + 
                      '. C = ' + str(C) + 
                      ', gamma = '  + str(gamma_kernel) +
                      '\n')
                
                # Entrenar modelo               
                model = SVC(C = C, gamma = gamma_kernel, probability = True, random_state = random_state)
               
                model.fit(X_train, np.array(y_train))

                # Generar predicciones
                pred_train_p = model.predict_proba(X_train)
                pred_val_p = model.predict_proba(X_val)

                # Calcular métricas de evaluación
                auc_train = metric(y_train, pred_train_p[:, 1])
                auc_val = metric(y_val, pred_val_p[:, 1])                                            

                print('Fin de iteracion ' + str(num_iter) + 
                     '. C = ' + str(C) + 
                      ', gamma = '  + str(gamma_kernel) +
                      '. AUC train = '  + str(auc_train) + 
                      ' -  AUC val = '  + str(auc_val)  + 
                      '\n')
                grid_results = grid_results.append(pd.DataFrame(data={'model':'SVM',
                                                                     'params': [{'C':[C],
                                                                              'gamma_kernel':[gamma_kernel]}],
                                                                      'auc_train':[auc_train],
                                                                      'auc_val':[auc_val]},
                                                               columns=['model','params', 'auc_train', 'auc_val']), 
                                                   ignore_index=True)
                
    # Decision Tree
    if params['model'] == 'decision tree':
        for max_depth in params['max_depth']:
            for min_samples_split in params['min_samples_split']:  
                for min_samples_leaf in params['min_samples_leaf']:  
                    for max_features in params['max_features']:  
                
                        # Actualizar contador
                        num_iter += 1; 

                        # print control iteracion modelo
                        print('Inicio de iteracion ' + str(num_iter) + 
                              '. max_depth = ' + str(max_depth) + 
                              ', min_samples_split = '  + str(min_samples_split) +
                              ', min_samples_leaf = '  + str(min_samples_leaf) +
                              ', max_features = '  + str(max_features) +
                              '\n')

                        # Entrenar modelo               
                        model = DecisionTreeClassifier(max_depth = max_depth,
                                                      min_samples_split = min_samples_split,
                                                      min_samples_leaf = min_samples_leaf,
                                                      max_features = max_features, random_state = random_state)

                        model.fit(X_train, np.array(y_train))

                        # Generar predicciones
                        pred_train_p = model.predict_proba(X_train)
                        pred_val_p = model.predict_proba(X_val)

                        # Calcular métricas de evaluación
                        auc_train = metric(y_train, pred_train_p[:, 1])
                        auc_val = metric(y_val, pred_val_p[:, 1])                                            

                        print('Fin de iteracion ' + str(num_iter) + 
                             '. max_depth = ' + str(max_depth) + 
                              ', min_samples_split = '  + str(min_samples_split) +
                              ', min_samples_leaf = '  + str(min_samples_leaf) +
                              ', max_features = '  + str(max_features) +
                              '. AUC train = '  + str(auc_train) + 
                              ' -  AUC val = '  + str(auc_val)  + 
                              '\n')
                        grid_results = grid_results.append(pd.DataFrame(data={'model':'decision tree',
                                                                              'params': [{'max_depth':[max_depth],
                                                                                          'min_samples_split':[min_samples_split],
                                                                                          'min_samples_leaf':[min_samples_leaf],
                                                                                          'max_features':[max_features]}],
                                                                      'auc_train':[auc_train],
                                                                      'auc_val':[auc_val]},
                                                                       columns=['model','params', 'auc_train', 'auc_val']), 
                                                           ignore_index=True)  
                        
    
    # Random Forest
    if params['model'] == 'random forest':
        for n_trees in params['n_trees']:
            for max_depth in params['max_depth']:
                for min_samples_split in params['min_samples_split']:  
                    for min_samples_leaf in params['min_samples_leaf']:  
                        for max_features in params['max_features']:  
                
                            # Actualizar contador
                            num_iter += 1; 

                            # print control iteracion modelo
                            print('Inicio de iteracion ' + str(num_iter) + 
                                  '. n_trees = ' + str(n_trees) + 
                                  ', max_depth = ' + str(max_depth) + 
                                  ', min_samples_split = '  + str(min_samples_split) +
                                  ', min_samples_leaf = '  + str(min_samples_leaf) +
                                  ', max_features = '  + str(max_features) +
                                  '\n')

                            # Entrenar modelo               
                            model = RandomForestClassifier(n_estimators = n_trees,
                                                          max_depth = max_depth,
                                                          min_samples_split = min_samples_split,
                                                          min_samples_leaf = min_samples_leaf,
                                                          max_features = max_features, random_state = random_state)

                            model.fit(X_train, np.array(y_train))

                            # Generar predicciones
                            pred_train_p = model.predict_proba(X_train)
                            pred_val_p = model.predict_proba(X_val)

                            # Calcular métricas de evaluación
                            auc_train = metric(y_train, pred_train_p[:, 1])
                            auc_val = metric(y_val, pred_val_p[:, 1])                                            

                            print('Fin de iteracion ' + str(num_iter) + 
                                 '. n_trees = ' + str(n_trees) + 
                                  ', max_depth = ' + str(max_depth) + 
                                  ', min_samples_split = '  + str(min_samples_split) +
                                  ', min_samples_leaf = '  + str(min_samples_leaf) +
                                  ', max_features = '  + str(max_features) +
                                  '. AUC train = '  + str(auc_train) + 
                                  ' -  AUC val = '  + str(auc_val)  + 
                                  '\n')
                            grid_results = grid_results.append(pd.DataFrame(data={'model':'random forest',
                                                                                  'params': [{'n_trees':[n_trees],
                                                                                              'max_depth':[max_depth],
                                                                                              'min_samples_split':[min_samples_split],
                                                                                              'min_samples_leaf':[min_samples_leaf],
                                                                                              'max_features':[max_features]}],
                                                                          'auc_train':[auc_train],
                                                                          'auc_val':[auc_val]},
                                                                           columns=['model','params', 'auc_train', 'auc_val']), 
                                                               ignore_index=True)  
    
    # XGBOOST
    if params['model'] == 'xgboost':
         for nrounds in params['nrounds']:
            for eta in params['eta']:
                for gamma in params['gamma']:
                    for max_depth in params['max_depth']:
                        for min_child_weight in params['min_child_weight']:
                            for subsample in params['subsample']:
                                for colsample_bytree in params['colsample_bytree']:
                                    for num_parallel_tree in params['num_parallel_tree']:
                                        for lamda in params['lambda']:
                                            for alpha in params['alpha']:
                                            
                                                # Actualizar contador
                                                num_iter += 1; 

                                                # print control iteracion modelo
                                                print('Inicio de iteracion ' + str(num_iter) + 
                                                      '. Parametro nrounds = ' + str(nrounds) + 
                                                      ', parametro eta = '  + str(eta) +
                                                      ', parametro gamma = '  + str(gamma) +
                                                      ', parametro max_depth = '  + str(max_depth) +
                                                      ', parametro min_child_weight = '  + str(min_child_weight) +
                                                      ', parametro subsample = '  + str(subsample) +
                                                      ', parametro colsample_bytree = '  + str(colsample_bytree) +
                                                      ', parametro num_parallel_tree = '  + str(num_parallel_tree) +
                                                      ', parametro lambda = '  + str(lamda) +
                                                      ', parametro alpha = '  + str(alpha) + 
                                                      '\n')
                                                # Entrenar modelo
                                                model = XGBClassifier(nthread = nthread, 
                                                                      scale_pos_weight = scale_pos_weight,
                                                                      random_state = random_state,
                                                                      n_estimators = nrounds,
                                                                      learning_rate = eta, 
                                                                      gamma = gamma,
                                                                      max_depth = max_depth,
                                                                      min_child_weight = min_child_weight ,
                                                                      subsample = subsample,
                                                                      colsample_bytree = colsample_bytree,
                                                                      num_parallel_tree = num_parallel_tree,
                                                                      reg_lambda = lamda,
                                                                      reg_alpha = alpha)
                                                model.fit(X_train, np.array(y_train))

                                                # Generar predicciones
                                                pred_train_p = model.predict_proba(X_train)
                                                pred_val_p = model.predict_proba(X_val)

                                                # Calcular métricas de evaluación
                                                auc_train = metric(y_train, pred_train_p[:, 1])
                                                auc_val = metric(y_val, pred_val_p[:, 1])                                            

                                                print('Fin de iteracion ' + str(num_iter) + 
                                                      '. Parametro nrounds = ' + str(nrounds) + 
                                                      ', parametro eta = ' + str(eta) + 
                                                      ', parametro gamma = '  + str(gamma) +
                                                      ', parametro max_depth = '  + str(max_depth) +
                                                      ', parametro min_child_weight = '  + str(min_child_weight) +
                                                      ', parametro subsample = '  + str(subsample) +
                                                      ', parametro colsample_bytree = '  + str(colsample_bytree) +
                                                      ', parametro num_parallel_tree = '  + str(num_parallel_tree) +
                                                      ', parametro lambda = '  + str(lamda) +
                                                      ', parametro alpha = '  + str(alpha) + 
                                                      '. AUC train = '  + str(auc_train) + 
                                                      ' -  AUC val = '  + str(auc_val)  + 
                                                      '\n')
                                                grid_results = grid_results.append(pd.DataFrame(data={'model':'xgboost',
                                                                                              'params': [{'nrounds':[nrounds],
                                                                                              'eta':[eta],
                                                                                              'gamma':[gamma],
                                                                                              'max_depth':[max_depth],
                                                                                              'min_child_weight':[min_child_weight],
                                                                                              'subsample':[subsample],
                                                                                              'colsample_bytree':[colsample_bytree],
                                                                                              'num_parallel_tree':[num_parallel_tree],
                                                                                              'lamda':[lamda],
                                                                                              'alpha':[alpha]}],
                                                                                              'auc_train':[auc_train],
                                                                                              'auc_val':[auc_val]},
                                                                                               columns=['model', 'params', 'auc_train', 'auc_val']), 
                                                                                   ignore_index=True)
# Out:
# Inicio de iteracion 1. Regularizacion = l1, Lambda = 1
#
# Fin de iteracion 1. Regularizacion = l1, Lambda = 1. AUC train = 0.9405726419572065 -  AUC val = 0.9380485570316079
#
# Inicio de iteracion 2. Regularizacion = l1, Lambda = 10
#
# Fin de iteracion 2. Regularizacion = l1, Lambda = 10. AUC train = 0.9405195563294215 -  AUC val = 0.9380142006413192
#
# Inicio de iteracion 3. Regularizacion = l1, Lambda = 100
#
# Fin de iteracion 3. Regularizacion = l1, Lambda = 100. AUC train = 0.9405131901612924 -  AUC val = 0.9378447091158957
#
# Inicio de iteracion 4. Regularizacion = l2, Lambda = 1
#
# Fin de iteracion 4. Regularizacion = l2, Lambda = 1. AUC train = 0.9405310051640405 -  AUC val = 0.9384264773247823
#
# Inicio de iteracion 5. Regularizacion = l2, Lambda = 10
#
# Fin de iteracion 5. Regularizacion = l2, Lambda = 10. AUC train = 0.9405154491241771 -  AUC val = 0.9389509848831882
#
# Inicio de iteracion 6. Regularizacion = l2, Lambda = 100
#
# Fin de iteracion 6. Regularizacion = l2, Lambda = 100. AUC train = 0.9405136008818169 -  AUC val = 0.9389028859367842
#
# Inicio de iteracion 7. Regularizacion = none, Lambda = 1
# C:\Users\jprada.SGSMAD\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# C:\Users\jprada.SGSMAD\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1510: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\jprada.SGSMAD\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# Fin de iteracion 7. Regularizacion = none, Lambda = 1. AUC train = 0.9405109825384735 -  AUC val = 0.9388811268896015
#
# Inicio de iteracion 8. Regularizacion = none, Lambda = 10
#
# Fin de iteracion 8. Regularizacion = none, Lambda = 10. AUC train = 0.9405109825384735 -  AUC val = 0.9388811268896015
#
# Inicio de iteracion 9. Regularizacion = none, Lambda = 100
# C:\Users\jprada.SGSMAD\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1510: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   "Setting penalty='none' will ignore the C and l1_ratio "
# C:\Users\jprada.SGSMAD\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# Fin de iteracion 9. Regularizacion = none, Lambda = 100. AUC train = 0.9405109825384735 -  AUC val = 0.9388811268896015
#
# Inicio de iteracion 10. C = 0.6169806179116835, gamma = 0.9294555738186685
#
# Fin de iteracion 10. C = 0.6169806179116835, gamma = 0.9294555738186685. AUC train = 0.8880986283731386 -  AUC val = 0.7195321804855704
#
# Inicio de iteracion 11. C = 0.6169806179116835, gamma = 3.26e-09
#
# Fin de iteracion 11. C = 0.6169806179116835, gamma = 3.26e-09. AUC train = 0.9380300252105392 -  AUC val = 0.9377565277141547
#
# Inicio de iteracion 12. C = 0.6169806179116835, gamma = 3.255e-09
#
# Fin de iteracion 12. C = 0.6169806179116835, gamma = 3.255e-09. AUC train = 0.9388052088603713 -  AUC val = 0.9386509390746679
#
# Inicio de iteracion 13. C = 0.6169806179116835, gamma = 3.25e-09
#
# Fin de iteracion 13. C = 0.6169806179116835, gamma = 3.25e-09. AUC train = 0.9393317525727148 -  AUC val = 0.93872022446175
#
# Inicio de iteracion 14. C = 0.005, gamma = 0.9294555738186685
#
# Fin de iteracion 14. C = 0.005, gamma = 0.9294555738186685. AUC train = 0.8446667811550128 -  AUC val = 0.7233171094823637
#
# Inicio de iteracion 15. C = 0.005, gamma = 3.26e-09
#
# Fin de iteracion 15. C = 0.005, gamma = 3.26e-09. AUC train = 0.9374311946858925 -  AUC val = 0.938617727897389
#
# Inicio de iteracion 16. C = 0.005, gamma = 3.255e-09
#
# Fin de iteracion 16. C = 0.005, gamma = 3.255e-09. AUC train = 0.937950704809255 -  AUC val = 0.9385948236371966
#
# Inicio de iteracion 17. C = 0.005, gamma = 3.25e-09
#
# Fin de iteracion 17. C = 0.005, gamma = 3.25e-09. AUC train = 0.9387099216986992 -  AUC val = 0.938599404489235
#
# Inicio de iteracion 18. C = 0.0045, gamma = 0.9294555738186685
#
# Fin de iteracion 18. C = 0.0045, gamma = 0.9294555738186685. AUC train = 0.8074073959985041 -  AUC val = 0.6424765231333028
#
# Inicio de iteracion 19. C = 0.0045, gamma = 3.26e-09
#
# Fin de iteracion 19. C = 0.0045, gamma = 3.26e-09. AUC train = 0.9380594687381357 -  AUC val = 0.9391468163078333
#
# Inicio de iteracion 20. C = 0.0045, gamma = 3.255e-09
#
# Fin de iteracion 20. C = 0.0045, gamma = 3.255e-09. AUC train = 0.9378792907780664 -  AUC val = 0.9378847915712322
#
# Inicio de iteracion 21. C = 0.0045, gamma = 3.25e-09
#
# Fin de iteracion 21. C = 0.0045, gamma = 3.25e-09. AUC train = 0.9384323259642371 -  AUC val = 0.9384322033898305
#
# Inicio de iteracion 22. C = 0.004, gamma = 0.9294555738186685
#
# Fin de iteracion 22. C = 0.004, gamma = 0.9294555738186685. AUC train = 0.8060725542940446 -  AUC val = 0.6683526110856619
#
# Inicio de iteracion 23. C = 0.004, gamma = 3.26e-09
#
# Fin de iteracion 23. C = 0.004, gamma = 3.26e-09. AUC train = 0.937680861424692 -  AUC val = 0.9392258360054969
#
# Inicio de iteracion 24. C = 0.004, gamma = 3.255e-09
#
# Fin de iteracion 24. C = 0.004, gamma = 3.255e-09. AUC train = 0.9374562486378839 -  AUC val = 0.9379225836005497
#
# Inicio de iteracion 25. C = 0.004, gamma = 3.25e-09
#
# Fin de iteracion 25. C = 0.004, gamma = 3.25e-09. AUC train = 0.9386955978204089 -  AUC val = 0.9387860742098029
#
# Inicio de iteracion 26. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 26. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9528682539474734 -  AUC val = 0.9116468163078334
#
# Inicio de iteracion 27. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 27. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.8702412700710778 -  AUC val = 0.8109654145671096
#
# Inicio de iteracion 28. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 28. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9383539553541655 -  AUC val = 0.9164137654603756
#
# Inicio de iteracion 29. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 29. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9530335432885315 -  AUC val = 0.9043540998625745
#
# Inicio de iteracion 30. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 30. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.8455758596958152 -  AUC val = 0.8009591158955566
#
# Inicio de iteracion 31. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 31. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9372514017763149 -  AUC val = 0.9213278744846543
#
# Inicio de iteracion 32. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 32. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9519405132928415 -  AUC val = 0.9373505497022447
#
# Inicio de iteracion 33. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 33. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.8536474934624844 -  AUC val = 0.814023705909299
#
# Inicio de iteracion 34. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 34. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9369083987983344 -  AUC val = 0.9225314933577646
#
# Inicio de iteracion 35. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 35. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9527901143676971 -  AUC val = 0.9116468163078334
#
# Inicio de iteracion 36. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 36. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.8711624905373841 -  AUC val = 0.8128956710948236
#
# Inicio de iteracion 37. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 37. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9380487386644344 -  AUC val = 0.9183302794319743
#
# Inicio de iteracion 38. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 38. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9530335432885315 -  AUC val = 0.9043540998625745
#
# Inicio de iteracion 39. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 39. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.8455758596958152 -  AUC val = 0.8009591158955566
#
# Inicio de iteracion 40. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 40. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9372514017763149 -  AUC val = 0.9213278744846543
#
# Inicio de iteracion 41. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 41. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9519405132928415 -  AUC val = 0.9373505497022447
#
# Inicio de iteracion 42. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 42. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.8536474934624844 -  AUC val = 0.814023705909299
#
# Inicio de iteracion 43. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 43. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9369083987983344 -  AUC val = 0.9225314933577646
#
# Inicio de iteracion 44. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 44. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9525775664962948 -  AUC val = 0.9118924644983969
#
# Inicio de iteracion 45. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 45. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.8725759595522428 -  AUC val = 0.8114280806229958
#
# Inicio de iteracion 46. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 46. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9374453902140187 -  AUC val = 0.9213719651855247
#
# Inicio de iteracion 47. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None
# Fin de iteracion 47. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9528344721843376 -  AUC val = 0.9046587265231334
#
# Inicio de iteracion 48. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 48. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.8518989791798065 -  AUC val = 0.8002994732020156
#
# Inicio de iteracion 49. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 49. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9372514017763149 -  AUC val = 0.9213278744846543
#
# Inicio de iteracion 50. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 50. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9519405132928415 -  AUC val = 0.9373505497022447
#
# Inicio de iteracion 51. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 51. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.8536474934624844 -  AUC val = 0.814023705909299
#
# Inicio de iteracion 52. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 52. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9369083987983344 -  AUC val = 0.9225314933577646
#
# Inicio de iteracion 53. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 53. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9999149551814063 -  AUC val = 0.644000229042602
#
# Inicio de iteracion 54. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 54. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9992416558916704 -  AUC val = 0.6617487402656893
#
# Inicio de iteracion 55. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 55. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9984391849969952 -  AUC val = 0.6870190105359598
#
# Inicio de iteracion 56. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 56. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9882555749535437 -  AUC val = 0.7446060467246908
#
# Inicio de iteracion 57. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 57. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.9659633847786461 -  AUC val = 0.8804563673843335
#
# Inicio de iteracion 58. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 58. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9764609649930063 -  AUC val = 0.8123488318827302
#
# Inicio de iteracion 59. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 59. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9686876940173165 -  AUC val = 0.8797480531378836
#
# Inicio de iteracion 60. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 60. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.913151065832596 -  AUC val = 0.8528240952817224
#
# Inicio de iteracion 61. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 61. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9518961811462338 -  AUC val = 0.9124524736601008
#
# Inicio de iteracion 62. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 62. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9982930968404553 -  AUC val = 0.6700555428309666
#
# Inicio de iteracion 63. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 63. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9941298795844432 -  AUC val = 0.6949055199267065
#
# Inicio de iteracion 64. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 64. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9926857348804148 -  AUC val = 0.7520505038937243
#
# Inicio de iteracion 65. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 65. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9882555749535437 -  AUC val = 0.7446060467246908
#
# Inicio de iteracion 66. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 66. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.9659633847786461 -  AUC val = 0.8804563673843335
#
# Inicio de iteracion 67. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 67. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9764609649930063 -  AUC val = 0.8123488318827302
#
# Inicio de iteracion 68. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 68. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9686876940173165 -  AUC val = 0.8797480531378836
#
# Inicio de iteracion 69. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 69. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.913151065832596 -  AUC val = 0.8528240952817224
#
# Inicio de iteracion 70. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 70. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9518961811462338 -  AUC val = 0.9124524736601008
#
# Inicio de iteracion 71. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 71. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9876233990563182 -  AUC val = 0.7808360054970225
#
# Inicio de iteracion 72. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 72. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9790553838658196 -  AUC val = 0.7841857535501603
#
# Inicio de iteracion 73. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 73. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9804277808282333 -  AUC val = 0.8095951672010994
#
# Inicio de iteracion 74. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 74. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9830428897474659 -  AUC val = 0.7791422354557948
#
# Inicio de iteracion 75. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 75. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.9693830695352414 -  AUC val = 0.8377147274393036
#
# Inicio de iteracion 76. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 76. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9613218064618148 -  AUC val = 0.8601448694457169
#
# Inicio de iteracion 77. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 77. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9686876940173165 -  AUC val = 0.8797480531378836
#
# Inicio de iteracion 78. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 78. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.913151065832596 -  AUC val = 0.8528240952817224
#
# Inicio de iteracion 79. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 79. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9518961811462338 -  AUC val = 0.9124524736601008
#
# Inicio de iteracion 80. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None
# Fin de iteracion 80. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9601792589728958 -  AUC val = 0.9378899450297756
#
# Inicio de iteracion 81. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 81. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9479723369458771 -  AUC val = 0.9334860284012827
#
# Inicio de iteracion 82. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 82. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.948205985584223 -  AUC val = 0.9340740952817224
#
# Inicio de iteracion 83. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 83. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9583790709142357 -  AUC val = 0.9382243472285846
#
# Inicio de iteracion 84. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 84. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.9430418167400958 -  AUC val = 0.9265231333027943
#
# Inicio de iteracion 85. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 85. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9459041024049484 -  AUC val = 0.9313948694457169
#
# Inicio de iteracion 86. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 86. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9565642252668592 -  AUC val = 0.9393105817682088
#
# Inicio de iteracion 87. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 87. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9412557728694964 -  AUC val = 0.9322177049931287
#
# Inicio de iteracion 88. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 88. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9428410514137385 -  AUC val = 0.9326334173156208
#
# Inicio de iteracion 89. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 89. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9598253975710503 -  AUC val = 0.937924874026569
#
# Inicio de iteracion 90. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 90. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.947226545483576 -  AUC val = 0.9298373797526343
#
# Inicio de iteracion 91. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 91. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9485057858970379 -  AUC val = 0.9347480531378837
#
# Inicio de iteracion 92. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 92. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9583790709142357 -  AUC val = 0.9382243472285846
#
# Inicio de iteracion 93. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 93. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.9430418167400958 -  AUC val = 0.9265231333027943
#
# Inicio de iteracion 94. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 94. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9459041024049484 -  AUC val = 0.9313948694457169
#
# Inicio de iteracion 95. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 95. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9565642252668592 -  AUC val = 0.9393105817682088
#
# Inicio de iteracion 96. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 96. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.9412557728694964 -  AUC val = 0.9322177049931287
#
# Inicio de iteracion 97. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 97. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9428410514137385 -  AUC val = 0.9326334173156208
#
# Inicio de iteracion 98. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 98. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9588199793972317 -  AUC val = 0.9379334631241412
#
# Inicio de iteracion 99. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 99. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9456313069666159 -  AUC val = 0.9320190105359596
#
# Inicio de iteracion 100. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 100. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9487590207703936 -  AUC val = 0.9365569170865781
#
# Inicio de iteracion 101. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 101. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9575713376628412 -  AUC val = 0.9384499541914796
#
# Inicio de iteracion 102. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 102. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.944132510762803 -  AUC val = 0.9277130096197892
#
# Inicio de iteracion 103. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 103. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9475667504279837 -  AUC val = 0.9373843334860283
#
# Inicio de iteracion 104. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 104. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9565642252668592 -  AUC val = 0.9393105817682088
#
# Inicio de iteracion 105. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 105. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.9412557728694964 -  AUC val = 0.9322177049931287
#
# Inicio de iteracion 106. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 106. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9428410514137385 -  AUC val = 0.9326334173156208
#
# Inicio de iteracion 107. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 107. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9997012008184635 -  AUC val = 0.8551677737059092
#
# Inicio de iteracion 108. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
# Fin de iteracion 108. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9990463839523277 -  AUC val = 0.9070934493815849
#
# Inicio de iteracion 109. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 109. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9989943764659194 -  AUC val = 0.8948076042143839
#
# Inicio de iteracion 110. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 110. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9882754948989795 -  AUC val = 0.9252416399450296
#
# Inicio de iteracion 111. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 111. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.9782244705748265 -  AUC val = 0.9419485799358682
#
# Inicio de iteracion 112. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 112. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9752208200394651 -  AUC val = 0.9400280577187358
#
# Inicio de iteracion 113. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 113. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9685006108184302 -  AUC val = 0.9338015345854329
#
# Inicio de iteracion 114. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 114. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.956811556032676 -  AUC val = 0.939656436097114
#
# Inicio de iteracion 115. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 115. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9563192048039926 -  AUC val = 0.9382506871278058
#
# Inicio de iteracion 116. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 116. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9985085710955944 -  AUC val = 0.8789647274393037
#
# Inicio de iteracion 117. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 117. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9954225197550154 -  AUC val = 0.9080582913421895
#
# Inicio de iteracion 118. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 118. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9962019132902231 -  AUC val = 0.9216777370590931
#
# Inicio de iteracion 119. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 119. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9882754948989795 -  AUC val = 0.9252416399450296
#
# Inicio de iteracion 120. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 120. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.9782244705748265 -  AUC val = 0.9419485799358682
#
# Inicio de iteracion 121. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 121. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9752208200394651 -  AUC val = 0.9400280577187358
#
# Inicio de iteracion 122. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 122. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9685006108184302 -  AUC val = 0.9338015345854329
#
# Inicio de iteracion 123. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 123. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.956811556032676 -  AUC val = 0.939656436097114
#
# Inicio de iteracion 124. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 124. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9563192048039926 -  AUC val = 0.9382506871278058
#
# Inicio de iteracion 125. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 125. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9884282829340745 -  AUC val = 0.91756069628951
#
# Inicio de iteracion 126. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 126. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9835219182291374 -  AUC val = 0.9394766376546038
#
# Inicio de iteracion 127. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 127. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.983035009047403 -  AUC val = 0.9250343563902885
#
# Inicio de iteracion 128. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 128. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9822136963486688 -  AUC val = 0.9305491296381126
#
# Inicio de iteracion 129. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 129. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.972847882209461 -  AUC val = 0.9393758589097573
#
# Inicio de iteracion 130. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 130. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9667637764006661 -  AUC val = 0.9380754695373339
#
# Inicio de iteracion 131. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 131. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9685006108184302 -  AUC val = 0.9338015345854329
#
# Inicio de iteracion 132. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 132. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.956811556032676 -  AUC val = 0.939656436097114
#
# Inicio de iteracion 133. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 133. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9563192048039926 -  AUC val = 0.9382506871278058
#
# Inicio de iteracion 134. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 134. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9632982192954963 -  AUC val = 0.9424049473202015
#
# Inicio de iteracion 135. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 135. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9486503338516112 -  AUC val = 0.931816307833257
#
# Inicio de iteracion 136. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
# Fin de iteracion 136. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9524241110403474 -  AUC val = 0.9373740265689419
#
# Inicio de iteracion 137. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 137. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9612168673678179 -  AUC val = 0.9422022446174987
#
# Inicio de iteracion 138. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 138. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.946296032465404 -  AUC val = 0.9317035043518095
#
# Inicio de iteracion 139. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 139. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9492612549616964 -  AUC val = 0.936235112230875
#
# Inicio de iteracion 140. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 140. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9581283517040923 -  AUC val = 0.9428023362345396
#
# Inicio de iteracion 141. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 141. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9446784096798614 -  AUC val = 0.9320464956481905
#
# Inicio de iteracion 142. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 142. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9468309702784659 -  AUC val = 0.9360702015574898
#
# Inicio de iteracion 143. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 143. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9630113310091685 -  AUC val = 0.9423808978469994
#
# Inicio de iteracion 144. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 144. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9479078538235386 -  AUC val = 0.9317739349519011
#
# Inicio de iteracion 145. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 145. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9514803266152292 -  AUC val = 0.9362912276683463
#
# Inicio de iteracion 146. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 146. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9612168673678179 -  AUC val = 0.9422022446174987
#
# Inicio de iteracion 147. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 147. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.946296032465404 -  AUC val = 0.9317035043518095
#
# Inicio de iteracion 148. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 148. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9492612549616964 -  AUC val = 0.936235112230875
#
# Inicio de iteracion 149. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 149. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9581283517040923 -  AUC val = 0.9428023362345396
#
# Inicio de iteracion 150. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 150. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.9446784096798614 -  AUC val = 0.9320464956481905
#
# Inicio de iteracion 151. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 151. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9468309702784659 -  AUC val = 0.9360702015574898
#
# Inicio de iteracion 152. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 152. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9614234854616486 -  AUC val = 0.9425137425561155
#
# Inicio de iteracion 153. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 153. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9477338366713359 -  AUC val = 0.9336240265689418
#
# Inicio de iteracion 154. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 154. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9503416553012597 -  AUC val = 0.9364223545579478
#
# Inicio de iteracion 155. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 155. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9603270670216317 -  AUC val = 0.9421759047182775
#
# Inicio de iteracion 156. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 156. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.945265329309299 -  AUC val = 0.9315947091158956
#
# Inicio de iteracion 157. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 157. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9489414063532817 -  AUC val = 0.9357512597343106
#
# Inicio de iteracion 158. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 158. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9581283517040923 -  AUC val = 0.9428023362345396
#
# Inicio de iteracion 159. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 159. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.9446784096798614 -  AUC val = 0.9320464956481905
#
# Inicio de iteracion 160. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 160. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9468309702784659 -  AUC val = 0.9360702015574898
#
# Inicio de iteracion 161. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 161. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9999997946397378 -  AUC val = 0.9210186669720567
#
# Inicio de iteracion 162. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 162. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9998992194513134 -  AUC val = 0.9349478928080625
#
# Inicio de iteracion 163. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 163. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9999375704802838 -  AUC val = 0.9353636051305544
#
# Inicio de iteracion 164. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None
# Fin de iteracion 164. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9916932800731494 -  AUC val = 0.9328378378378378
#
# Inicio de iteracion 165. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 165. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.9802856715267739 -  AUC val = 0.942750229042602
#
# Inicio de iteracion 166. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 166. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9802040921626052 -  AUC val = 0.9429208657810352
#
# Inicio de iteracion 167. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 167. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9701896733051938 -  AUC val = 0.9422743930371049
#
# Inicio de iteracion 168. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 168. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.95751422183991 -  AUC val = 0.9398259276225377
#
# Inicio de iteracion 169. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 169. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9577188376711837 -  AUC val = 0.940412276683463
#
# Inicio de iteracion 170. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 170. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9997861172868932 -  AUC val = 0.9238387540082456
#
# Inicio de iteracion 171. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 171. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9981211076208423 -  AUC val = 0.9385753550160332
#
# Inicio de iteracion 172. n_trees = 100, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# ...
#
# Inicio de iteracion 1241. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1241. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1. AUC train = 0.9573624092660604 -  AUC val = 0.9413965872652313
#
# Inicio de iteracion 1242. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0
# Fin de iteracion 1242. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0. AUC train = 0.9238955147521828 -  AUC val = 0.893125858909757
#
# Inicio de iteracion 1243. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1
#
# Fin de iteracion 1243. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1. AUC train = 0.9286568694419567 -  AUC val = 0.9174553366926248
#
# Inicio de iteracion 1244. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0
#
# Fin de iteracion 1244. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0. AUC train = 0.927135817319725 -  AUC val = 0.8867464498396701
#
# Inicio de iteracion 1245. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1245. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1. AUC train = 0.925048330254213 -  AUC val = 0.9112654603756298
#
# Inicio de iteracion 1246. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0
#
# Fin de iteracion 1246. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0. AUC train = 0.9785932462657161 -  AUC val = 0.9341027256069628
#
# Inicio de iteracion 1247. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1
#
# Fin de iteracion 1247. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1. AUC train = 0.9790690916633232 -  AUC val = 0.932490838295923
#
# Inicio de iteracion 1248. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0
#
# Fin de iteracion 1248. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0. AUC train = 0.979210559213963 -  AUC val = 0.9323173385249657
#
# Inicio de iteracion 1249. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1249. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 0.1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1. AUC train = 0.9786922555821411 -  AUC val = 0.9348694457169033
#
# Inicio de iteracion 1250. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0
#
# Fin de iteracion 1250. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0. AUC train = 0.9808352155884867 -  AUC val = 0.9205949381584975
#
# Inicio de iteracion 1251. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1
#
# Fin de iteracion 1251. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1. AUC train = 0.9806080614684336 -  AUC val = 0.921177851580394
#
# Inicio de iteracion 1252. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0
#
# Fin de iteracion 1252. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0. AUC train = 0.9813177351946161 -  AUC val = 0.923262139257902
#
# Inicio de iteracion 1253. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1253. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1. AUC train = 0.9802549444975386 -  AUC val = 0.9237677508016491
#
# Inicio de iteracion 1254. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0
#
# Fin de iteracion 1254. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0. AUC train = 0.9891196539268862 -  AUC val = 0.9348791800274852
#
# Inicio de iteracion 1255. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1
# Fin de iteracion 1255. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1. AUC train = 0.9881989211912025 -  AUC val = 0.9356258589097572
#
# Inicio de iteracion 1256. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0
#
# Fin de iteracion 1256. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0. AUC train = 0.9884347261123018 -  AUC val = 0.9352662620247366
#
# Inicio de iteracion 1257. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1257. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1. AUC train = 0.987825730254675 -  AUC val = 0.9351746449839671
#
# Inicio de iteracion 1258. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0
#
# Fin de iteracion 1258. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0. AUC train = 0.9998072693939023 -  AUC val = 0.9224295693999084
#
# Inicio de iteracion 1259. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1
#
# Fin de iteracion 1259. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1. AUC train = 0.9995447162986482 -  AUC val = 0.9227582455336693
#
# Inicio de iteracion 1260. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0
#
# Fin de iteracion 1260. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0. AUC train = 0.9997075926566251 -  AUC val = 0.9199604901511682
#
# Inicio de iteracion 1261. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1261. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1. AUC train = 0.9995042346569573 -  AUC val = 0.921747022446175
#
# Inicio de iteracion 1262. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0
#
# Fin de iteracion 1262. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0. AUC train = 0.9998072693939023 -  AUC val = 0.9224284241868987
#
# Inicio de iteracion 1263. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1
#
# Fin de iteracion 1263. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1. AUC train = 0.9995447162986483 -  AUC val = 0.9227582455336693
#
# Inicio de iteracion 1264. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0
#
# Fin de iteracion 1264. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0. AUC train = 0.9997075669865924 -  AUC val = 0.9199604901511682
#
# Inicio de iteracion 1265. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1
#
# Fin de iteracion 1265. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1. AUC train = 0.9995042603269899 -  AUC val = 0.921747022446175

# %% [markdown]
# Veamos los resultados.

# %%
grid_results
# Out:
#                     model                                             params  \
# 0     Logistic Regression         {'regularization': ['l1'], 'penalty': [1]}
# 1     Logistic Regression        {'regularization': ['l1'], 'penalty': [10]}
# 2     Logistic Regression       {'regularization': ['l1'], 'penalty': [100]}
# 3     Logistic Regression         {'regularization': ['l2'], 'penalty': [1]}
# 4     Logistic Regression        {'regularization': ['l2'], 'penalty': [10]}
# 5     Logistic Regression       {'regularization': ['l2'], 'penalty': [100]}
# 6     Logistic Regression       {'regularization': ['none'], 'penalty': [1]}
# 7     Logistic Regression      {'regularization': ['none'], 'penalty': [10]}
# 8     Logistic Regression     {'regularization': ['none'], 'penalty': [100]}
# 9                     SVM  {'C': [0.6169806179116835], 'gamma_kernel': [0...
# 10                    SVM  {'C': [0.6169806179116835], 'gamma_kernel': [3...
# 11                    SVM  {'C': [0.6169806179116835], 'gamma_kernel': [3...
# 12                    SVM  {'C': [0.6169806179116835], 'gamma_kernel': [3...
# 13                    SVM  {'C': [0.005], 'gamma_kernel': [0.929455573818...
# 14                    SVM         {'C': [0.005], 'gamma_kernel': [3.26e-09]}
# 15                    SVM        {'C': [0.005], 'gamma_kernel': [3.255e-09]}
# 16                    SVM         {'C': [0.005], 'gamma_kernel': [3.25e-09]}
# 17                    SVM  {'C': [0.0045], 'gamma_kernel': [0.92945557381...
# 18                    SVM        {'C': [0.0045], 'gamma_kernel': [3.26e-09]}
# 19                    SVM       {'C': [0.0045], 'gamma_kernel': [3.255e-09]}
# 20                    SVM        {'C': [0.0045], 'gamma_kernel': [3.25e-09]}
# 21                    SVM  {'C': [0.004], 'gamma_kernel': [0.929455573818...
# 22                    SVM         {'C': [0.004], 'gamma_kernel': [3.26e-09]}
# 23                    SVM        {'C': [0.004], 'gamma_kernel': [3.255e-09]}
# 24                    SVM         {'C': [0.004], 'gamma_kernel': [3.25e-09]}
# 25          decision tree  {'max_depth': [6], 'min_samples_split': [2], '...
# 26          decision tree  {'max_depth': [6], 'min_samples_split': [2], '...
# 27          decision tree  {'max_depth': [6], 'min_samples_split': [2], '...
# 28          decision tree  {'max_depth': [6], 'min_samples_split': [2], '...
# 29          decision tree  {'max_depth': [6], 'min_samples_split': [2], '...
# ...                   ...                                                ...
# 1235              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1236              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1237              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1238              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1239              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1240              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1241              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1242              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1243              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1244              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1245              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1246              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1247              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1248              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1249              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1250              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1251              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1252              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1253              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1254              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1255              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1256              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1257              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1258              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1259              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1260              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1261              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1262              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1263              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1264              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
#
#       auc_train   auc_val
# 0      0.940573  0.938049
# 1      0.940520  0.938014
# 2      0.940513  0.937845
# 3      0.940531  0.938426
# 4      0.940515  0.938951
# 5      0.940514  0.938903
# 6      0.940511  0.938881
# 7      0.940511  0.938881
# 8      0.940511  0.938881
# 9      0.888099  0.719532
# 10     0.938030  0.937757
# 11     0.938805  0.938651
# 12     0.939332  0.938720
# 13     0.844667  0.723317
# 14     0.937431  0.938618
# 15     0.937951  0.938595
# 16     0.938710  0.938599
# 17     0.807407  0.642477
# 18     0.938059  0.939147
# 19     0.937879  0.937885
# 20     0.938432  0.938432
# 21     0.806073  0.668353
# 22     0.937681  0.939226
# 23     0.937456  0.937923
# 24     0.938696  0.938786
# 25     0.952868  0.911647
# 26     0.870241  0.810965
# 27     0.938354  0.916414
# 28     0.953034  0.904354
# 29     0.845576  0.800959
# ...         ...       ...
# 1235   0.889727  0.861805
# 1236   0.903581  0.871227
# 1237   0.958057  0.940567
# 1238   0.957435  0.941490
# 1239   0.957565  0.941389
# 1240   0.957362  0.941397
# 1241   0.923896  0.893126
# 1242   0.928657  0.917455
# 1243   0.927136  0.886746
# 1244   0.925048  0.911265
# 1245   0.978593  0.934103
# 1246   0.979069  0.932491
# 1247   0.979211  0.932317
# 1248   0.978692  0.934869
# 1249   0.980835  0.920595
# 1250   0.980608  0.921178
# 1251   0.981318  0.923262
# 1252   0.980255  0.923768
# 1253   0.989120  0.934879
# 1254   0.988199  0.935626
# 1255   0.988435  0.935266
# 1256   0.987826  0.935175
# 1257   0.999807  0.922430
# 1258   0.999545  0.922758
# 1259   0.999708  0.919960
# 1260   0.999504  0.921747
# 1261   0.999807  0.922428
# 1262   0.999545  0.922758
# 1263   0.999708  0.919960
# 1264   0.999504  0.921747
#
# [1265 rows x 4 columns]

# %% [markdown]
# Vamos a analizar el mejor resultado para cada familia de modelos.

# %%
grid_results.groupby(['model'], sort=False)['auc_val'].max().sort_values()
# Out:
# model
# decision tree          0.937351
# Logistic Regression    0.938951
# SVM                    0.939226
# random forest          0.943565
# xgboost                0.945624
# Name: auc_val, dtype: float64

# %% [markdown]
# Nos quedamos con la mejor combinación de familia de modelos + hiperparámetros.

# %%
best_params = grid_results.iloc[grid_results['auc_val'].idxmax()]

# %% [markdown]
# Juntamos validación y train para entrenar el modelo final.

# %%
print('Train data size = ' + str(X_train.shape))
print('Train target size = ' + str(y_train.shape))
print('Validation data size = ' + str(X_val.shape))
print('Validation target size = ' + str(y_val.shape))

# Combinar train y validación
X_train = pd.concat((X_train,X_val), axis = 0)
y_train = np.concatenate((y_train, y_val), axis = 0)

del X_val, y_val

print('Train data size = ' + str(X_train.shape))
print('Train target size = ' + str(y_train.shape))
# Out:
# Train data size = (22894, 22)
# Train target size = (22894,)
# Validation data size = (4905, 22)
# Validation target size = (4905,)
# Train data size = (27799, 22)
# Train target size = (27799,)

# %% [markdown]
# Y ahora entrenamos el modelo final.

# %%
# Logistic Regression
if best_params['model'] == 'logistic regression':       

    # Entrenar modelo
    if best_params['params']['regularization'] == 'l1':
        model = LogisticRegression(penalty = best_params['params']['regularization'][0], solver = 'liblinear', C = best_params['params']['penalty'][0], random_state = random_state)
    else:
        model = LogisticRegression(penalty = best_params['params']['regularization'][0],solver = 'lbfgs', C = best_params['params']['penalty'][0], random_state = random_state)


# SVM
elif best_params['model'] == 'SVM':

    model = SVC(C = best_params['params']['C'][0], gamma = best_params['params']['gamma_kernel'][0], probability = True, 
                random_state = random_state)             


# Decision Tree
elif best_params['model'] == 'decision tree':
    model = DecisionTreeClassifier(max_depth = int(best_params['params']['max_depth'][0]),
                                                  min_samples_split = int(best_params['params']['min_samples_split'][0]),
                                                  min_samples_leaf = int(best_params['params']['min_samples_leaf'][0]),
                                                  max_features = int(best_params['params']['max_features'][0]), 
                                   random_state = random_state)


# Random Forest
elif best_params['model'] == 'random forest':
    model = RandomForestClassifier(n_estimators = int(best_params['params']['n_trees'][0]),
                                                      max_depth = int(best_params['params']['max_depth'][0]),
                                                      min_samples_split = int(best_params['params']['min_samples_split'][0]),
                                                      min_samples_leaf = int(best_params['params']['min_samples_leaf'][0]),
                                                      max_features = int(best_params['params']['max_features'][0]), 
                                                      random_state = random_state)

# XGBOOST
elif best_params['model'] == 'xgboost':
    model = XGBClassifier(nthread = nthread, 
                                                              scale_pos_weight = scale_pos_weight,
                                                              random_state = random_state,
                                                              n_estimators = int(best_params['params']['nrounds'][0]), 
                                                              learning_rate = best_params['params']['eta'][0], 
                                                              gamma = best_params['params']['gamma'][0],
                                                              max_depth = int(best_params['params']['max_depth'][0]),
                                                              min_child_weight = best_params['params']['min_child_weight'][0],
                                                              subsample = best_params['params']['subsample'][0],
                                                              colsample_bytree = best_params['params']['colsample_bytree'][0],
                                                              num_parallel_tree  = int(best_params['params']['num_parallel_tree'][0]),
                                                              reg_lambda = best_params['params']['lamda'][0],
                                                              reg_alpha = best_params['params']['alpha'][0])

# Entrenar modelo
model.fit(X_train, np.array(y_train))

# Generar predicciones
pred_train_p = model.predict_proba(X_train)
pred_test_p = model.predict_proba(X_test)

# Calcular métricas de evaluación
auc_train = metric(y_train, pred_train_p[:, 1])
auc_test = metric(y_test, pred_test_p[:, 1]) 

results = pd.DataFrame()
results = results.append(pd.DataFrame(data={'model':best_params['model'],'auc_train':[auc_train],'auc_test':[auc_test]}, columns=['model',  'auc_train', 'auc_test']), ignore_index=True)

# %%
results
# Out:
#      model  auc_train  auc_test
# 0  xgboost   0.961011  0.937501
