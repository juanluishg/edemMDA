# %% [markdown]
# # Predicción de Exitus (fallecimiento). Comparativa final

# %%
# Load Libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd 
import multiprocessing
import random
from sklearn.metrics import roc_auc_score as metric




from sklearn.preprocessing import scale
from sklearn.preprocessing import OneHotEncoder
import timeit

# %% [markdown]
# ## Dataset

# %% [markdown]
# Leamos el dataset a utilizar.

# %%
# Load the dataset 
X = pd.read_csv("datasets/dat_sanidad.csv", sep=';', decimal=',', encoding='latin-1')
X.shape
# Out:
# (32706, 10)

# %% [markdown]
# El dataset consta de:
#
# - 32706 **filas** o instancias
# - 10 **columnas** o variables.
#
# Veamos su contenido.

# %%
X.head()
# Out:
#    gravedad  pct_mortalidad_norma  edad_dias  numproc  potencial_ambul  proc  \
# 0         4              0.408730      12596       21                0     1
# 1         4              0.306931      20973       22                0     1
# 2         4              0.278481      19611       19                0     1
# 3         3              0.150289      13583       22                0     1
# 4         1              0.016573      18042        2                0     1
#
#    estancia_esperada tipgrd  tiping  exitus
# 0                151      Q       1       0
# 1                 99      Q       1       0
# 2                 87      Q       1       0
# 3                100      Q       1       0
# 4                 44      Q       1       0

# %% [markdown]
# - **gravedad**: Gravedad dentro del GRD. Valores de 1 a 4.
#
# - **pct_mortalidad_norma**: Tasa de mortalidad histórica para ese GRD.
#
# - **edad_dias**: Edad en días del paciente.
#
# - **numproc**: Número de procedimientos que se han llevado a cabo al paciente a las 24 horas.
#
# - **potencial_ambul**: Flag (valor 0 = no / 1 = sí) que indica si el caso se ha catalogado como potencialmente ambulatorio, es decir, no requiere ingreso.
#
# - **proc**: Procedencia del paciente.
#
# - **estancia_esperada**: Número de días que se espera que el paciente esté ingresado en el hospital por este episodio asistencial.
#
# - **tipgrd**: GRD médico (M) o de quirófano (Q).
#
# - **tiping**: Tipo de ingreso: Programado, urgente...
#
# - **exitus**: 1 = El paciente falleció.
#
# De estas variables, fecing la usaremos para realizar el split en train/validacion/test, exitus es el target y las 10 variables restantes serán el input de nuestro modelo.

# %% [markdown]
# ## Pre-procesado

# %% [markdown]
# ### One-Hot Encoding

# %% [markdown]
# Utilizaremos la técnica de one-hot encoding.
#
# <img src="../figures/oh.png" width="50%">

# %% [markdown]
# Seleccionemos las variables categóricas en primer lugar.

# %%
categorical_vars = set(['gravedad', 'proc', 'tiping', 'tipgrd'])
numerical_vars = set(X.columns) - categorical_vars
categorical_vars = list(categorical_vars)
numerical_vars = list(numerical_vars)

# %%
print(categorical_vars)
print(numerical_vars)
# Out:
# ['proc', 'tiping', 'gravedad', 'tipgrd']
# ['pct_mortalidad_norma', 'potencial_ambul', 'exitus', 'edad_dias', 'numproc', 'estancia_esperada']

# %% [markdown]
# Realizamos one hot encoding de las variables categoricas

# %%
ohe = OneHotEncoder(sparse = False)
ohe_fit = ohe.fit(X[categorical_vars])
X_ohe = pd.DataFrame(ohe.fit_transform(X[categorical_vars]))
X_ohe.columns = pd.DataFrame(ohe_fit.get_feature_names())

# %% [markdown]
# Volvemos a pegar las variables numéricas.

# %%
X = pd.concat((X_ohe, X[numerical_vars].reset_index()), axis=1)
del X['index']

# %% [markdown]
# ### Tipificar

# %% [markdown]
# Ahora vamos a tipificar los datos, es decir, llevarlos a media 0 y desviación estándar 1.

# %% [markdown]
# <img src="../figures/tipify.png" width="50%">

# %%
y = X['exitus']
del X['exitus']

# %%
X_scale = pd.DataFrame(scale(X))
X_scale.columns = X.columns
X = X_scale
X.columns = X_scale.columns
print(X.head())
# Out:
#     (x0_1,)   (x0_2,)   (x0_3,)   (x0_4,)   (x0_6,)   (x0_7,)   (x0_8,)  \
# 0  0.589002 -0.471911 -0.128712 -0.140259 -0.118114 -0.009578 -0.134718
# 1  0.589002 -0.471911 -0.128712 -0.140259 -0.118114 -0.009578 -0.134718
# 2  0.589002 -0.471911 -0.128712 -0.140259 -0.118114 -0.009578 -0.134718
# 3  0.589002 -0.471911 -0.128712 -0.140259 -0.118114 -0.009578 -0.134718
# 4  0.589002 -0.471911 -0.128712 -0.140259 -0.118114 -0.009578 -0.134718
#
#     (x0_9,)   (x1_1,)  (x1_2,)  ...   (x2_2,)   (x2_3,)   (x2_4,)   (x3_M,)  \
# 0 -0.090724  0.589285  -0.5681  ... -0.435743 -0.417921  4.120705 -1.554964
# 1 -0.090724  0.589285  -0.5681  ... -0.435743 -0.417921  4.120705 -1.554964
# 2 -0.090724  0.589285  -0.5681  ... -0.435743 -0.417921  4.120705 -1.554964
# 3 -0.090724  0.589285  -0.5681  ... -0.435743  2.392797 -0.242677 -1.554964
# 4 -0.090724  0.589285  -0.5681  ... -0.435743 -0.417921 -0.242677 -1.554964
#
#     (x3_Q,)  pct_mortalidad_norma  potencial_ambul  edad_dias   numproc  \
# 0  1.554964              5.678791        -0.258527  -0.713484  6.002393
# 1  1.554964              4.151382        -0.258527   0.186170  6.357038
# 2  1.554964              3.724521        -0.258527   0.039897  5.293102
# 3  1.554964              1.801116        -0.258527  -0.607484  6.357038
# 4  1.554964             -0.205167        -0.258527  -0.128607 -0.735868
#
#    estancia_esperada
# 0          19.632898
# 1          12.641211
# 2          11.027745
# 3          12.775667
# 4           5.246158
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Split en Train/Validación/Test

# %% [markdown]
# Utilizaremos a modo de ejemplo los ratios habitualmente recomendados:
#
# • Train: 70%.
#
# • Validación: 15%.
#
# • Test: 15%.

# %%
perc_values = [0.7, 0.15, 0.15];

# %% [markdown]
# Creamos los conjuntos de train, validacion y test con el tamaño seleccionado pero respetando el eje temporal.

# %%
# dimensiones de los conjuntos de train y test
n_train = int(X.shape[0] * perc_values[0])
n_val = int(X.shape[0] * perc_values[1])
n_test = int(X.shape[0] * perc_values[2])

# selección del conjunto de train
X_train = X.iloc[:n_train]
y_train = y.iloc[:n_train]

# selección del conjunto de validación
X_val = X.iloc[(n_train):(n_train+n_val)]
y_val = y.iloc[(n_train):(n_train+n_val)]

# selección del conjunto de test
X_test = X.iloc[(n_train+n_val):]
y_test = y.iloc[(n_train+n_val):]

# %% [markdown]
# Visualizamos el tamaño de los 3 subdatasets

# %%
print('Train data size = ' + str(X_train.shape))
print('Train target size = ' + str(y_train.shape))
print('Validation data size = ' + str(X_val.shape))
print('Validation target size = ' + str(y_val.shape))
print('Test data size = ' + str(X_test.shape))
print('Test target size = ' + str(y_test.shape))
# Out:
# Train data size = (22894, 22)
# Train target size = (22894,)
# Validation data size = (4905, 22)
# Validation target size = (4905,)
# Test data size = (4907, 22)
# Test target size = (4907,)

# %% [markdown]
# # Grid Search

# %% [markdown]
# Vamos a proceder a realizar un grid search que compare todos los modelos de clasificación que hemos visto, es decir:
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Importamos todos los modelos que vamos a usar.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %% [markdown]
# Importamos la métrica, en este caso AUC.

# %%
from sklearn.metrics import roc_auc_score as metric;

# %% [markdown]
# Definimos algunos parámetros generales.

# %%
random_state = 1;
nthread = multiprocessing.cpu_count() - 1;
scale_pos_weight = sum(y_train == 0) / sum(y_train == 1);

# %% [markdown]
# Vamos a calcular los puntos recomendados por Cherkassky para la SVM.

# %%
n = X_train.shape[0];
d = X_train.shape[1];
m = np.mean(y_train);
s = np.std(y_train);
C_cherk = np.max([np.abs(m + 3*s),np.abs(m - 3*s)]);
gamma_cherk = np.power(0.2, 1/d)

# %% [markdown]
# Definimos el grid a llevar a cabo

# %%
# Regresion Logística
regularization_values = ['l1', 'l2', 'none'];
penalty_values = [1, 10, 100];

# SVM
C_values = [C_cherk, 5e-03, 4.5e-03, 4e-03];
gamma_kernel_values = [gamma_cherk, 3.26e-09, 3.255e-09, 3.25e-09];

# Arbol de Decision
max_depth_values = [None, 6, 20];
min_samples_split_values = [2, 5, 20];
min_samples_leaf_values = [1, 5, 20];
max_features_values = [None, 1, 2];

# Random Forest
ntrees_values = [10, 100, 1000];

# Xgboost
nrounds_values = [10, 100]
eta_values = [0.3, 0.99]
gamma_values = [0, 1]
max_depth_values = [6, 20]
min_child_weight_values = [1, 20]
subsample_values = [0.1, 1]
colsample_bytree_values = [0.1, 1]
num_parallel_tree_values = [1, 20]
lambda_values = [0, 1]
alpha_values = [0, 1]

# %%
params_values = [{'model': 'logistic regression',
                  'regularization': regularization_values,
                 'penalty': penalty_values},
                 {'model': 'svm',
                  'C': C_values,
                 'gamma_kernel': gamma_kernel_values},
                 {'model': 'decision tree',
                 'max_depth': max_depth_values,
                 'min_samples_split': min_samples_split_values,
                 'min_samples_leaf': min_samples_leaf_values,
                 'max_features': max_features_values},
                 {'model': 'random forest',
                  'n_trees': ntrees_values,
                 'max_depth': max_depth_values,
                 'min_samples_split': min_samples_split_values,
                 'min_samples_leaf': min_samples_leaf_values,
                 'max_features': max_features_values},
                 {'model': 'xgboost',
                  'nrounds': nrounds_values,
                  'eta': eta_values,
                 'gamma': gamma_values,
                 'max_depth': max_depth_values,
                 'min_child_weight': min_child_weight_values,
                 'subsample': subsample_values,
                 'colsample_bytree': colsample_bytree_values,
                 'num_parallel_tree': num_parallel_tree_values,
                 'lambda': lambda_values,
                 'alpha': alpha_values}]

# %%
total_iteraciones = 0
for params in params_values:
    if params['model'] == 'logistic regression':
        n = len(params['regularization'])*len(params['penalty'])
    elif params['model'] == 'svm':
        n = len(params['C'])*len(params['gamma_kernel'])
    elif params['model'] == 'decision tree':
        n = len(params['max_depth'])*len(params['min_samples_split'])*len(params['min_samples_leaf'])*len(params['max_features'])
    elif params['model'] == 'random forest':
        n = len(params['n_trees'])*len(params['max_depth'])*len(params['min_samples_split'])*len(params['min_samples_leaf'])*len(params['max_features'])
    elif params['model'] == 'xgboost':
        n = len(params['nrounds'])*len(params['eta'])*len(params['gamma'])*len(params['max_depth'])*len(params['min_child_weight'])*len(params['subsample'])*len(params['colsample_bytree'])*len(params['num_parallel_tree'])*len(params['lambda'])*len(params['alpha'])
    total_iteraciones = total_iteraciones + n;
    print(str(n)+ ' iteraciones de ' + str(params['model']))
print(str(total_iteraciones)+ ' iteraciones en total')
# Out:
# 9 iteraciones de logistic regression
# 16 iteraciones de svm
# 54 iteraciones de decision tree
# 162 iteraciones de random forest
# 1024 iteraciones de xgboost
# 1265 iteraciones en total

# %%
grid_results = pd.DataFrame();
num_iter = 0
for params in params_values:
    
    # Logistic Regression
    if params['model'] == 'logistic regression':
        for regularization in params['regularization']:
            for penalty in params['penalty']:  
                
                # Actualizar contador
                num_iter += 1; 
                
                # print control iteracion modelo
                print('Inicio de iteracion ' + str(num_iter) + 
                      '. Regularizacion = ' + str(regularization) + 
                      ', Lambda = '  + str(penalty) +
                      '\n')
                
                # Entrenar modelo
                if regularization == 'l1':
                    model = LogisticRegression(penalty = regularization, solver = 'liblinear', C = penalty, random_state = random_state)
                else:
                    model = LogisticRegression(penalty = regularization,solver = 'lbfgs', C = penalty, random_state = random_state)
               
                model.fit(X_train, np.array(y_train))

                # Generar predicciones
                pred_train_p = model.predict_proba(X_train)
                pred_val_p = model.predict_proba(X_val)

                # Calcular métricas de evaluación
                auc_train = metric(y_train, pred_train_p[:, 1])
                auc_val = metric(y_val, pred_val_p[:, 1])                                            

                print('Fin de iteracion ' + str(num_iter) + 
                     '. Regularizacion = ' + str(regularization) + 
                      ', Lambda = '  + str(penalty) +
                      '. AUC train = '  + str(auc_train) + 
                      ' -  AUC val = '  + str(auc_val)  + 
                      '\n')
                grid_results = grid_results.append(pd.DataFrame(data={'model':'Logistic Regression',
                                                                      'params': [{'regularization':[regularization],
                                                                                  'penalty':[penalty]}],
                                                                      'auc_train':[auc_train],
                                                                      'auc_val':[auc_val]},
                                                               columns=['model','params', 'auc_train', 'auc_val']), 
                                                   ignore_index=True)
                
     
    # SVM
    if params['model'] == 'svm':
        for C in params['C']:
            for gamma_kernel in params['gamma_kernel']:  
                
                # Actualizar contador
                num_iter += 1; 
                
                # print control iteracion modelo
                print('Inicio de iteracion ' + str(num_iter) + 
                      '. C = ' + str(C) + 
                      ', gamma = '  + str(gamma_kernel) +
                      '\n')
                
                # Entrenar modelo               
                model = SVC(C = C, gamma = gamma_kernel, probability = True, random_state = random_state)
               
                model.fit(X_train, np.array(y_train))

                # Generar predicciones
                pred_train_p = model.predict_proba(X_train)
                pred_val_p = model.predict_proba(X_val)

                # Calcular métricas de evaluación
                auc_train = metric(y_train, pred_train_p[:, 1])
                auc_val = metric(y_val, pred_val_p[:, 1])                                            

                print('Fin de iteracion ' + str(num_iter) + 
                     '. C = ' + str(C) + 
                      ', gamma = '  + str(gamma_kernel) +
                      '. AUC train = '  + str(auc_train) + 
                      ' -  AUC val = '  + str(auc_val)  + 
                      '\n')
                grid_results = grid_results.append(pd.DataFrame(data={'model':'SVM',
                                                                     'params': [{'C':[C],
                                                                              'gamma_kernel':[gamma_kernel]}],
                                                                      'auc_train':[auc_train],
                                                                      'auc_val':[auc_val]},
                                                               columns=['model','params', 'auc_train', 'auc_val']), 
                                                   ignore_index=True)
                
    # Decision Tree
    if params['model'] == 'decision tree':
        for max_depth in params['max_depth']:
            for min_samples_split in params['min_samples_split']:  
                for min_samples_leaf in params['min_samples_leaf']:  
                    for max_features in params['max_features']:  
                
                        # Actualizar contador
                        num_iter += 1; 

                        # print control iteracion modelo
                        print('Inicio de iteracion ' + str(num_iter) + 
                              '. max_depth = ' + str(max_depth) + 
                              ', min_samples_split = '  + str(min_samples_split) +
                              ', min_samples_leaf = '  + str(min_samples_leaf) +
                              ', max_features = '  + str(max_features) +
                              '\n')

                        # Entrenar modelo               
                        model = DecisionTreeClassifier(max_depth = max_depth,
                                                      min_samples_split = min_samples_split,
                                                      min_samples_leaf = min_samples_leaf,
                                                      max_features = max_features, random_state = random_state)

                        model.fit(X_train, np.array(y_train))

                        # Generar predicciones
                        pred_train_p = model.predict_proba(X_train)
                        pred_val_p = model.predict_proba(X_val)

                        # Calcular métricas de evaluación
                        auc_train = metric(y_train, pred_train_p[:, 1])
                        auc_val = metric(y_val, pred_val_p[:, 1])                                            

                        print('Fin de iteracion ' + str(num_iter) + 
                             '. max_depth = ' + str(max_depth) + 
                              ', min_samples_split = '  + str(min_samples_split) +
                              ', min_samples_leaf = '  + str(min_samples_leaf) +
                              ', max_features = '  + str(max_features) +
                              '. AUC train = '  + str(auc_train) + 
                              ' -  AUC val = '  + str(auc_val)  + 
                              '\n')
                        grid_results = grid_results.append(pd.DataFrame(data={'model':'decision tree',
                                                                              'params': [{'max_depth':[max_depth],
                                                                                          'min_samples_split':[min_samples_split],
                                                                                          'min_samples_leaf':[min_samples_leaf],
                                                                                          'max_features':[max_features]}],
                                                                      'auc_train':[auc_train],
                                                                      'auc_val':[auc_val]},
                                                                       columns=['model','params', 'auc_train', 'auc_val']), 
                                                           ignore_index=True)  
                        
    
    # Random Forest
    if params['model'] == 'random forest':
        for n_trees in params['n_trees']:
            for max_depth in params['max_depth']:
                for min_samples_split in params['min_samples_split']:  
                    for min_samples_leaf in params['min_samples_leaf']:  
                        for max_features in params['max_features']:  
                
                            # Actualizar contador
                            num_iter += 1; 

                            # print control iteracion modelo
                            print('Inicio de iteracion ' + str(num_iter) + 
                                  '. n_trees = ' + str(n_trees) + 
                                  ', max_depth = ' + str(max_depth) + 
                                  ', min_samples_split = '  + str(min_samples_split) +
                                  ', min_samples_leaf = '  + str(min_samples_leaf) +
                                  ', max_features = '  + str(max_features) +
                                  '\n')

                            # Entrenar modelo               
                            model = RandomForestClassifier(n_estimators = n_trees,
                                                          max_depth = max_depth,
                                                          min_samples_split = min_samples_split,
                                                          min_samples_leaf = min_samples_leaf,
                                                          max_features = max_features, random_state = random_state)

                            model.fit(X_train, np.array(y_train))

                            # Generar predicciones
                            pred_train_p = model.predict_proba(X_train)
                            pred_val_p = model.predict_proba(X_val)

                            # Calcular métricas de evaluación
                            auc_train = metric(y_train, pred_train_p[:, 1])
                            auc_val = metric(y_val, pred_val_p[:, 1])                                            

                            print('Fin de iteracion ' + str(num_iter) + 
                                 '. n_trees = ' + str(n_trees) + 
                                  ', max_depth = ' + str(max_depth) + 
                                  ', min_samples_split = '  + str(min_samples_split) +
                                  ', min_samples_leaf = '  + str(min_samples_leaf) +
                                  ', max_features = '  + str(max_features) +
                                  '. AUC train = '  + str(auc_train) + 
                                  ' -  AUC val = '  + str(auc_val)  + 
                                  '\n')
                            grid_results = grid_results.append(pd.DataFrame(data={'model':'random forest',
                                                                                  'params': [{'n_trees':[n_trees],
                                                                                              'max_depth':[max_depth],
                                                                                              'min_samples_split':[min_samples_split],
                                                                                              'min_samples_leaf':[min_samples_leaf],
                                                                                              'max_features':[max_features]}],
                                                                          'auc_train':[auc_train],
                                                                          'auc_val':[auc_val]},
                                                                           columns=['model','params', 'auc_train', 'auc_val']), 
                                                               ignore_index=True)  
    
    # XGBOOST
    if params['model'] == 'xgboost':
         for nrounds in params['nrounds']:
            for eta in params['eta']:
                for gamma in params['gamma']:
                    for max_depth in params['max_depth']:
                        for min_child_weight in params['min_child_weight']:
                            for subsample in params['subsample']:
                                for colsample_bytree in params['colsample_bytree']:
                                    for num_parallel_tree in params['num_parallel_tree']:
                                        for lamda in params['lambda']:
                                            for alpha in params['alpha']:
                                            
                                                # Actualizar contador
                                                num_iter += 1; 

                                                # print control iteracion modelo
                                                print('Inicio de iteracion ' + str(num_iter) + 
                                                      '. Parametro nrounds = ' + str(nrounds) + 
                                                      ', parametro eta = '  + str(eta) +
                                                      ', parametro gamma = '  + str(gamma) +
                                                      ', parametro max_depth = '  + str(max_depth) +
                                                      ', parametro min_child_weight = '  + str(min_child_weight) +
                                                      ', parametro subsample = '  + str(subsample) +
                                                      ', parametro colsample_bytree = '  + str(colsample_bytree) +
                                                      ', parametro num_parallel_tree = '  + str(num_parallel_tree) +
                                                      ', parametro lambda = '  + str(lamda) +
                                                      ', parametro alpha = '  + str(alpha) + 
                                                      '\n')
                                                # Entrenar modelo
                                                model = XGBClassifier(nthread = nthread, 
                                                                      scale_pos_weight = scale_pos_weight,
                                                                      random_state = random_state,
                                                                      n_estimators = nrounds,
                                                                      learning_rate = eta, 
                                                                      gamma = gamma,
                                                                      max_depth = max_depth,
                                                                      min_child_weight = min_child_weight ,
                                                                      subsample = subsample,
                                                                      colsample_bytree = colsample_bytree,
                                                                      num_parallel_tree = num_parallel_tree,
                                                                      reg_lambda = lamda,
                                                                      reg_alpha = alpha)
                                                model.fit(X_train, np.array(y_train))

                                                # Generar predicciones
                                                pred_train_p = model.predict_proba(X_train)
                                                pred_val_p = model.predict_proba(X_val)

                                                # Calcular métricas de evaluación
                                                auc_train = metric(y_train, pred_train_p[:, 1])
                                                auc_val = metric(y_val, pred_val_p[:, 1])                                            

                                                print('Fin de iteracion ' + str(num_iter) + 
                                                      '. Parametro nrounds = ' + str(nrounds) + 
                                                      ', parametro eta = ' + str(eta) + 
                                                      ', parametro gamma = '  + str(gamma) +
                                                      ', parametro max_depth = '  + str(max_depth) +
                                                      ', parametro min_child_weight = '  + str(min_child_weight) +
                                                      ', parametro subsample = '  + str(subsample) +
                                                      ', parametro colsample_bytree = '  + str(colsample_bytree) +
                                                      ', parametro num_parallel_tree = '  + str(num_parallel_tree) +
                                                      ', parametro lambda = '  + str(lamda) +
                                                      ', parametro alpha = '  + str(alpha) + 
                                                      '. AUC train = '  + str(auc_train) + 
                                                      ' -  AUC val = '  + str(auc_val)  + 
                                                      '\n')
                                                grid_results = grid_results.append(pd.DataFrame(data={'model':'xgboost',
                                                                                              'params': [{'nrounds':[nrounds],
                                                                                              'eta':[eta],
                                                                                              'gamma':[gamma],
                                                                                              'max_depth':[max_depth],
                                                                                              'min_child_weight':[min_child_weight],
                                                                                              'subsample':[subsample],
                                                                                              'colsample_bytree':[colsample_bytree],
                                                                                              'num_parallel_tree':[num_parallel_tree],
                                                                                              'lamda':[lamda],
                                                                                              'alpha':[alpha]}],
                                                                                              'auc_train':[auc_train],
                                                                                              'auc_val':[auc_val]},
                                                                                               columns=['model', 'params', 'auc_train', 'auc_val']), 
                                                                                   ignore_index=True)
# Out:
# Inicio de iteracion 1. Regularizacion = l1, Lambda = 1
#
# Fin de iteracion 1. Regularizacion = l1, Lambda = 1. AUC train = 0.9405732580379932 -  AUC val = 0.9380497022446176
#
# Inicio de iteracion 2. Regularizacion = l1, Lambda = 10
#
# Fin de iteracion 2. Regularizacion = l1, Lambda = 10. AUC train = 0.9405197616896837 -  AUC val = 0.9379363261566651
#
# Inicio de iteracion 3. Regularizacion = l1, Lambda = 100
#
# Fin de iteracion 3. Regularizacion = l1, Lambda = 100. AUC train = 0.9405132928414237 -  AUC val = 0.9377989005955107
#
# Inicio de iteracion 4. Regularizacion = l2, Lambda = 1
#
# Fin de iteracion 4. Regularizacion = l2, Lambda = 1. AUC train = 0.9405310051640405 -  AUC val = 0.9384264773247823
#
# Inicio de iteracion 5. Regularizacion = l2, Lambda = 10
#
# Fin de iteracion 5. Regularizacion = l2, Lambda = 10. AUC train = 0.9405154491241771 -  AUC val = 0.9389509848831882
#
# Inicio de iteracion 6. Regularizacion = l2, Lambda = 100
#
# Fin de iteracion 6. Regularizacion = l2, Lambda = 100. AUC train = 0.9405136008818171 -  AUC val = 0.9389017407237745
#
# Inicio de iteracion 7. Regularizacion = none, Lambda = 1
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# Fin de iteracion 7. Regularizacion = none, Lambda = 1. AUC train = 0.940510931198408 -  AUC val = 0.9388811268896015
#
# Inicio de iteracion 8. Regularizacion = none, Lambda = 10
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:1322: UserWarning: Setting penalty='none' will ignore the C and l1_ratio parameters
#   warnings.warn(
# Fin de iteracion 8. Regularizacion = none, Lambda = 10. AUC train = 0.940510931198408 -  AUC val = 0.9388811268896015
#
# Inicio de iteracion 9. Regularizacion = none, Lambda = 100
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Fin de iteracion 9. Regularizacion = none, Lambda = 100. AUC train = 0.940510931198408 -  AUC val = 0.9388811268896015
#
# Inicio de iteracion 10. C = 0.6169806179118057, gamma = 0.9294555738186685
#
# Fin de iteracion 10. C = 0.6169806179118057, gamma = 0.9294555738186685. AUC train = 0.888444763095118 -  AUC val = 0.719701672010994
#
# Inicio de iteracion 11. C = 0.6169806179118057, gamma = 3.26e-09
#
# Fin de iteracion 11. C = 0.6169806179118057, gamma = 3.26e-09. AUC train = 0.9381199730053935 -  AUC val = 0.9378458543289052
#
# Inicio de iteracion 12. C = 0.6169806179118057, gamma = 3.255e-09
#
# Fin de iteracion 12. C = 0.6169806179118057, gamma = 3.255e-09. AUC train = 0.9387003724465056 -  AUC val = 0.9385822262940907
#
# Inicio de iteracion 13. C = 0.6169806179118057, gamma = 3.25e-09
#
# Fin de iteracion 13. C = 0.6169806179118057, gamma = 3.25e-09. AUC train = 0.938591120787002 -  AUC val = 0.938858222629409
#
# Inicio de iteracion 14. C = 0.005, gamma = 0.9294555738186685
#
# Fin de iteracion 14. C = 0.005, gamma = 0.9294555738186685. AUC train = 0.844666524454685 -  AUC val = 0.7233211177278974
#
# Inicio de iteracion 15. C = 0.005, gamma = 3.26e-09
#
# Fin de iteracion 15. C = 0.005, gamma = 3.26e-09. AUC train = 0.9371579628570027 -  AUC val = 0.9386761337608795
#
# Inicio de iteracion 16. C = 0.005, gamma = 3.255e-09
#
# Fin de iteracion 16. C = 0.005, gamma = 3.255e-09. AUC train = 0.9378672258626607 -  AUC val = 0.9385948236371966
#
# Inicio de iteracion 17. C = 0.005, gamma = 3.25e-09
#
# Fin de iteracion 17. C = 0.005, gamma = 3.25e-09. AUC train = 0.9387096906684042 -  AUC val = 0.9385971140632158
#
# Inicio de iteracion 18. C = 0.0045, gamma = 0.9294555738186685
#
# Fin de iteracion 18. C = 0.0045, gamma = 0.9294555738186685. AUC train = 0.8074090388806018 -  AUC val = 0.6424696518552451
#
# Inicio de iteracion 19. C = 0.0045, gamma = 3.26e-09
#
# Fin de iteracion 19. C = 0.0045, gamma = 3.26e-09. AUC train = 0.9380594687381357 -  AUC val = 0.9391468163078333
#
# Inicio de iteracion 20. C = 0.0045, gamma = 3.255e-09
#
# Fin de iteracion 20. C = 0.0045, gamma = 3.255e-09. AUC train = 0.9382312782675193 -  AUC val = 0.9383749427393494
#
# Inicio de iteracion 21. C = 0.0045, gamma = 3.25e-09
#
# Fin de iteracion 21. C = 0.0045, gamma = 3.25e-09. AUC train = 0.9383065941436901 -  AUC val = 0.9385432890517637
#
# Inicio de iteracion 22. C = 0.004, gamma = 0.9294555738186685
#
# Fin de iteracion 22. C = 0.004, gamma = 0.9294555738186685. AUC train = 0.806074222846175 -  AUC val = 0.6683360054970224
#
# Inicio de iteracion 23. C = 0.004, gamma = 3.26e-09
#
# Fin de iteracion 23. C = 0.004, gamma = 3.26e-09. AUC train = 0.937680861424692 -  AUC val = 0.9392258360054969
#
# Inicio de iteracion 24. C = 0.004, gamma = 3.255e-09
#
# Fin de iteracion 24. C = 0.004, gamma = 3.255e-09. AUC train = 0.9373074651279021 -  AUC val = 0.9378034814475493
#
# Inicio de iteracion 25. C = 0.004, gamma = 3.25e-09
#
# Fin de iteracion 25. C = 0.004, gamma = 3.25e-09. AUC train = 0.9387138748837469 -  AUC val = 0.9387688960146587
#
# Inicio de iteracion 26. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 26. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9528682539474734 -  AUC val = 0.9118540998625746
#
# Inicio de iteracion 27. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 27. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9120161423434121 -  AUC val = 0.9066393724232708
#
# Inicio de iteracion 28. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 28. max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9302246410238441 -  AUC val = 0.9060581768208887
#
# Inicio de iteracion 29. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 29. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9530335432885315 -  AUC val = 0.9044262482821805
#
# Inicio de iteracion 30. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 30. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.9116929052906708 -  AUC val = 0.9060862345396243
#
# Inicio de iteracion 31. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 31. max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9140005642273205 -  AUC val = 0.9004953046266606
#
# Inicio de iteracion 32. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 32. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9519405132928415 -  AUC val = 0.9373505497022447
#
# Inicio de iteracion 33. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 33. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9114236266468289 -  AUC val = 0.9061114292258359
#
# Inicio de iteracion 34. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 34. max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9249330974770722 -  AUC val = 0.9184986257443886
#
# Inicio de iteracion 35. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 35. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9527901143676971 -  AUC val = 0.9116468163078334
#
# Inicio de iteracion 36. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 36. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9120161423434121 -  AUC val = 0.9066393724232708
#
# Inicio de iteracion 37. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 37. max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.92667837733562 -  AUC val = 0.8969588868529546
#
# Inicio de iteracion 38. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 38. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9530335432885315 -  AUC val = 0.9044262482821805
#
# Inicio de iteracion 39. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 39. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.9116929052906708 -  AUC val = 0.9060862345396243
#
# Inicio de iteracion 40. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 40. max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9140005642273205 -  AUC val = 0.9004953046266606
#
# Inicio de iteracion 41. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 41. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9519405132928415 -  AUC val = 0.9373505497022447
#
# Inicio de iteracion 42. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 42. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.9114236266468289 -  AUC val = 0.9061114292258359
#
# Inicio de iteracion 43. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 43. max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9249330974770722 -  AUC val = 0.9184986257443886
#
# Inicio de iteracion 44. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 44. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9525775664962948 -  AUC val = 0.9118924644983969
#
# Inicio de iteracion 45. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 45. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9120161423434121 -  AUC val = 0.9066393724232708
#
# Inicio de iteracion 46. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 46. max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9275109078386783 -  AUC val = 0.9140987173614292
#
# Inicio de iteracion 47. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 47. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9528344721843376 -  AUC val = 0.9046587265231334
#
# Inicio de iteracion 48. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 48. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.9116929052906708 -  AUC val = 0.9060862345396243
#
# Inicio de iteracion 49. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 49. max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9221360393655087 -  AUC val = 0.9034385020613835
# Inicio de iteracion 50. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 50. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9519405132928415 -  AUC val = 0.9373505497022447
#
# Inicio de iteracion 51. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 51. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.9114236266468289 -  AUC val = 0.9061114292258359
#
# Inicio de iteracion 52. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 52. max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9249330974770722 -  AUC val = 0.9184986257443886
#
# Inicio de iteracion 53. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 53. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9999149551814063 -  AUC val = 0.6336704076958315
#
# Inicio de iteracion 54. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 54. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9959436984305086 -  AUC val = 0.6603762024736601
#
# Inicio de iteracion 55. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 55. max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9987753597462569 -  AUC val = 0.6534671323866239
#
# Inicio de iteracion 56. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 56. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9882027973661519 -  AUC val = 0.7526288364635823
#
# Inicio de iteracion 57. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 57. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.9633618039666875 -  AUC val = 0.8628733394411361
#
# Inicio de iteracion 58. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 58. max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9647302734140861 -  AUC val = 0.8551694915254238
#
# Inicio de iteracion 59. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 59. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9686876940173165 -  AUC val = 0.8773511223087495
#
# Inicio de iteracion 60. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 60. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9389635416225464 -  AUC val = 0.920304054054054
#
# Inicio de iteracion 61. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 61. max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9263560387340259 -  AUC val = 0.9071243701328446
#
# Inicio de iteracion 62. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 62. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.99830598319691 -  AUC val = 0.6625040082455337
#
# Inicio de iteracion 63. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 63. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9860318056840127 -  AUC val = 0.7571174988547871
#
# Inicio de iteracion 64. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 64. max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9945312562169611 -  AUC val = 0.6908726523133302
#
# Inicio de iteracion 65. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 65. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9882027973661519 -  AUC val = 0.7526288364635823
#
# Inicio de iteracion 66. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 66. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.9633618039666875 -  AUC val = 0.8628733394411361
#
# Inicio de iteracion 67. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 67. max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9647302734140861 -  AUC val = 0.8551694915254238
#
# Inicio de iteracion 68. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 68. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9686876940173165 -  AUC val = 0.8773511223087495
#
# Inicio de iteracion 69. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 69. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.9389635416225464 -  AUC val = 0.920304054054054
#
# Inicio de iteracion 70. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 70. max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9263560387340259 -  AUC val = 0.9071243701328446
#
# Inicio de iteracion 71. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 71. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9876650871895498 -  AUC val = 0.7748448236371965
#
# Inicio de iteracion 72. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 72. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9733962967897314 -  AUC val = 0.8735673385249658
#
# Inicio de iteracion 73. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 73. max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9786028211879424 -  AUC val = 0.8219737746220797
#
# Inicio de iteracion 74. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 74. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9829930385438109 -  AUC val = 0.7807798900595512
#
# Inicio de iteracion 75. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 75. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.9689242690393991 -  AUC val = 0.8763960146587265
#
# Inicio de iteracion 76. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 76. max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9535489205366167 -  AUC val = 0.8744417086578105
#
# Inicio de iteracion 77. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 77. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9686876940173165 -  AUC val = 0.8773511223087495
#
# Inicio de iteracion 78. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 78. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.9389635416225464 -  AUC val = 0.920304054054054
#
# Inicio de iteracion 79. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 79. max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9263560387340259 -  AUC val = 0.9071243701328446
#
# Inicio de iteracion 80. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None
# Fin de iteracion 80. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.960114929870754 -  AUC val = 0.9379002519468621
#
# Inicio de iteracion 81. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 81. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9420210222166434 -  AUC val = 0.9294691937700412
#
# Inicio de iteracion 82. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 82. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9493552586217296 -  AUC val = 0.9374524736601009
#
# Inicio de iteracion 83. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 83. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9583903913986909 -  AUC val = 0.9382884791571233
#
# Inicio de iteracion 84. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 84. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.941062657212907 -  AUC val = 0.9263061154374713
#
# Inicio de iteracion 85. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 85. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.945516561920098 -  AUC val = 0.9331310123683004
#
# Inicio de iteracion 86. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 86. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9565642252668592 -  AUC val = 0.9393105817682088
#
# Inicio de iteracion 87. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 87. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9379051918411394 -  AUC val = 0.9264206367384333
#
# Inicio de iteracion 88. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 88. n_trees = 10, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9443212368437873 -  AUC val = 0.9369938158497481
#
# Inicio de iteracion 89. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 89. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9597491575736994 -  AUC val = 0.9377490838295923
#
# Inicio de iteracion 90. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 90. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9422435557307963 -  AUC val = 0.9298356619331195
#
# Inicio de iteracion 91. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 91. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9478060464735408 -  AUC val = 0.9350624141090242
#
# Inicio de iteracion 92. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 92. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9583903913986909 -  AUC val = 0.9382884791571233
#
# Inicio de iteracion 93. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 93. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.941062657212907 -  AUC val = 0.9263061154374713
#
# Inicio de iteracion 94. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 94. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.945516561920098 -  AUC val = 0.9331310123683004
#
# Inicio de iteracion 95. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 95. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9565642252668592 -  AUC val = 0.9393105817682088
#
# Inicio de iteracion 96. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 96. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.9379051918411394 -  AUC val = 0.9264206367384333
#
# Inicio de iteracion 97. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 97. n_trees = 10, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9443212368437873 -  AUC val = 0.9369938158497481
#
# Inicio de iteracion 98. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 98. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9588728853347872 -  AUC val = 0.9378166513971599
#
# Inicio de iteracion 99. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 99. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9469924091146071 -  AUC val = 0.9331069628950985
#
# Inicio de iteracion 100. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 100. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9470384611534111 -  AUC val = 0.9337969537333944
#
# Inicio de iteracion 101. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 101. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9575603765588449 -  AUC val = 0.938376660558864
#
# Inicio de iteracion 102. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 102. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.9424695803694072 -  AUC val = 0.9288015345854329
#
# Inicio de iteracion 103. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 103. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9462835568294737 -  AUC val = 0.935352153000458
#
# Inicio de iteracion 104. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 104. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9565642252668592 -  AUC val = 0.9393105817682088
#
# Inicio de iteracion 105. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 105. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.9379051918411394 -  AUC val = 0.9264206367384333
#
# Inicio de iteracion 106. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 106. n_trees = 10, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9443212368437873 -  AUC val = 0.9369938158497481
#
# Inicio de iteracion 107. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 107. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9996810241726998 -  AUC val = 0.8625206138341731
#
# Inicio de iteracion 108. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 108. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9987797493218619 -  AUC val = 0.8917624828218049
#
# Inicio de iteracion 109. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
# Fin de iteracion 109. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9993278558617391 -  AUC val = 0.8772366010077876
#
# Inicio de iteracion 110. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 110. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9882631476132132 -  AUC val = 0.9251706367384332
#
# Inicio de iteracion 111. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 111. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.9773075626740267 -  AUC val = 0.9362946633073751
#
# Inicio de iteracion 112. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 112. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9771087226001278 -  AUC val = 0.9371896472743929
#
# Inicio de iteracion 113. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 113. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9684890593036798 -  AUC val = 0.9337843563902887
#
# Inicio de iteracion 114. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 114. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9529757087046825 -  AUC val = 0.936032982134677
#
# Inicio de iteracion 115. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 115. n_trees = 10, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9558771925095871 -  AUC val = 0.9368655519926706
#
# Inicio de iteracion 116. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 116. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9985003566851052 -  AUC val = 0.8814401053595969
#
# Inicio de iteracion 117. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 117. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9949298604859388 -  AUC val = 0.913683577645442
#
# Inicio de iteracion 118. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 118. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.9960133412294354 -  AUC val = 0.916289509848832
#
# Inicio de iteracion 119. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 119. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9882631476132132 -  AUC val = 0.9251706367384332
#
# Inicio de iteracion 120. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 120. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.9773075626740267 -  AUC val = 0.9362946633073751
#
# Inicio de iteracion 121. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 121. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9771087226001278 -  AUC val = 0.9371896472743929
#
# Inicio de iteracion 122. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 122. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9684890593036798 -  AUC val = 0.9337843563902887
#
# Inicio de iteracion 123. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 123. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.9529757087046825 -  AUC val = 0.936032982134677
#
# Inicio de iteracion 124. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 124. n_trees = 10, max_depth = 20, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9558771925095871 -  AUC val = 0.9368655519926706
#
# Inicio de iteracion 125. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 125. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9884442496944625 -  AUC val = 0.9178515803939533
#
# Inicio de iteracion 126. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 126. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.983083576749419 -  AUC val = 0.9236921667430141
#
# Inicio de iteracion 127. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 127. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9832711220088958 -  AUC val = 0.9326505955107651
#
# Inicio de iteracion 128. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 128. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9821799915956312 -  AUC val = 0.9306052450755842
#
# Inicio de iteracion 129. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 129. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.9733573296799742 -  AUC val = 0.9326941136051304
#
# Inicio de iteracion 130. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 130. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9726224223115711 -  AUC val = 0.939518437929455
#
# Inicio de iteracion 131. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 131. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9684890593036798 -  AUC val = 0.9337843563902887
#
# Inicio de iteracion 132. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 132. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.9529757087046825 -  AUC val = 0.936032982134677
#
# Inicio de iteracion 133. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 133. n_trees = 10, max_depth = 20, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9558771925095871 -  AUC val = 0.9368655519926706
#
# Inicio de iteracion 134. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 134. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9632856923195006 -  AUC val = 0.9424770957398075
#
# Inicio de iteracion 135. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 135. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.9489030553243114 -  AUC val = 0.9339704535043518
#
# Inicio de iteracion 136. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 136. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9525589043824649 -  AUC val = 0.9373539853412735
#
# Inicio de iteracion 137. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None
# Fin de iteracion 137. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9612166106674901 -  AUC val = 0.9422526339899221
#
# Inicio de iteracion 138. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 138. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.9472261090930187 -  AUC val = 0.9334070087036189
#
# Inicio de iteracion 139. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 139. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9501498231463091 -  AUC val = 0.9375475263398991
#
# Inicio de iteracion 140. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 140. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9581280950037645 -  AUC val = 0.9428046266605588
#
# Inicio de iteracion 141. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 141. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9449751039187102 -  AUC val = 0.9332443884562529
#
# Inicio de iteracion 142. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 142. n_trees = 100, max_depth = 6, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9469806779096277 -  AUC val = 0.9365265689418232
#
# Inicio de iteracion 143. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 143. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = None. AUC train = 0.9630040920599251 -  AUC val = 0.9423969308291342
#
# Inicio de iteracion 144. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 144. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 1. AUC train = 0.9485329961317827 -  AUC val = 0.9337477095739808
#
# Inicio de iteracion 145. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 145. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 1, max_features = 2. AUC train = 0.951498834708862 -  AUC val = 0.9371071919377005
#
# Inicio de iteracion 146. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 146. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = None. AUC train = 0.9612166106674901 -  AUC val = 0.9422526339899221
#
# Inicio de iteracion 147. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 147. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 1. AUC train = 0.9472261090930187 -  AUC val = 0.9334070087036189
#
# Inicio de iteracion 148. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 148. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 5, max_features = 2. AUC train = 0.9501498231463091 -  AUC val = 0.9375475263398991
#
# Inicio de iteracion 149. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 149. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = None. AUC train = 0.9581280950037645 -  AUC val = 0.9428046266605588
#
# Inicio de iteracion 150. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 150. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 1. AUC train = 0.9449751039187102 -  AUC val = 0.9332443884562529
#
# Inicio de iteracion 151. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 151. n_trees = 100, max_depth = 6, min_samples_split = 5, min_samples_leaf = 20, max_features = 2. AUC train = 0.9469806779096277 -  AUC val = 0.9365265689418232
#
# Inicio de iteracion 152. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 152. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = None. AUC train = 0.9614297489496464 -  AUC val = 0.9425320659642694
#
# Inicio de iteracion 153. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 153. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 1. AUC train = 0.9485190573039843 -  AUC val = 0.9346140632157581
#
# Inicio de iteracion 154. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 154. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 1, max_features = 2. AUC train = 0.9503326451197546 -  AUC val = 0.9372898534127347
#
# Inicio de iteracion 155. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 155. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = None. AUC train = 0.9603332791695641 -  AUC val = 0.942204535043518
#
# Inicio de iteracion 156. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1
#
# Fin de iteracion 156. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 1. AUC train = 0.9477906957939395 -  AUC val = 0.9343999083829593
#
# Inicio de iteracion 157. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 157. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 5, max_features = 2. AUC train = 0.9492222108418411 -  AUC val = 0.9376122308749427
#
# Inicio de iteracion 158. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 158. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = None. AUC train = 0.9581280950037645 -  AUC val = 0.9428046266605588
#
# Inicio de iteracion 159. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 159. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 1. AUC train = 0.9449751039187102 -  AUC val = 0.9332443884562529
#
# Inicio de iteracion 160. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 160. n_trees = 100, max_depth = 6, min_samples_split = 20, min_samples_leaf = 20, max_features = 2. AUC train = 0.9469806779096277 -  AUC val = 0.9365265689418232
#
# Inicio de iteracion 161. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None
#
# Fin de iteracion 161. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = None. AUC train = 0.9999998459798033 -  AUC val = 0.921388570774164
#
# Inicio de iteracion 162. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1
#
# Fin de iteracion 162. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 1. AUC train = 0.999887000515711 -  AUC val = 0.9333549015116813
#
# Inicio de iteracion 163. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2
#
# Fin de iteracion 163. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 1, max_features = 2. AUC train = 0.9999232466019936 -  AUC val = 0.9344880897847001
#
# Inicio de iteracion 164. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None
#
# Fin de iteracion 164. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = None. AUC train = 0.9916807530971535 -  AUC val = 0.9329512139257902
#
# Inicio de iteracion 165. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1
# Fin de iteracion 165. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 1. AUC train = 0.9810003765793809 -  AUC val = 0.9431029546495646
#
# Inicio de iteracion 166. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2
#
# Fin de iteracion 166. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 5, max_features = 2. AUC train = 0.9808429679383857 -  AUC val = 0.942882501145213
#
# Inicio de iteracion 167. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None
#
# Fin de iteracion 167. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = None. AUC train = 0.9701867982615227 -  AUC val = 0.942246907924874
#
# Inicio de iteracion 168. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1
#
# Fin de iteracion 168. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 1. AUC train = 0.9588034222260898 -  AUC val = 0.9416886165826843
#
# Inicio de iteracion 169. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2
#
# Fin de iteracion 169. n_trees = 100, max_depth = 20, min_samples_split = 2, min_samples_leaf = 20, max_features = 2. AUC train = 0.9580589142654276 -  AUC val = 0.9406630783325699
#
# ...
#
# Inicio de iteracion 1255. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1
#
# [14:39:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1255. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1. AUC train = 0.986796772660799 -  AUC val = 0.9338759734310582
#
# Inicio de iteracion 1256. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0
#
# [14:39:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1256. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0. AUC train = 0.9871448583052695 -  AUC val = 0.9349845396243701
#
# Inicio de iteracion 1257. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1
#
# [14:39:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1257. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 0.1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1. AUC train = 0.9864979221391967 -  AUC val = 0.9342607650022904
#
# Inicio de iteracion 1258. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0
#
# [14:39:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1258. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 0. AUC train = 0.9998069613535089 -  AUC val = 0.9265672240036646
#
# Inicio de iteracion 1259. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1
#
# [14:39:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1259. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 0, parametro alpha = 1. AUC train = 0.9994311007335726 -  AUC val = 0.9228155061841503
#
# Inicio de iteracion 1260. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0
#
# [14:39:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1260. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 0. AUC train = 0.9997210694238335 -  AUC val = 0.9187706138341732
#
# Inicio de iteracion 1261. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1
#
# [14:39:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# Fin de iteracion 1261. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 1, parametro lambda = 1, parametro alpha = 1. AUC train = 0.9995794735230297 -  AUC val = 0.923993930371049
#
# Inicio de iteracion 1262. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:39:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fin de iteracion 1262. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 0. AUC train = 0.999806961353509 -  AUC val = 0.9265672240036646
#
# Inicio de iteracion 1263. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:40:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fin de iteracion 1263. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 0, parametro alpha = 1. AUC train = 0.9994311007335726 -  AUC val = 0.9228143609711406
#
# Inicio de iteracion 1264. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:40:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fin de iteracion 1264. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 0. AUC train = 0.9997210694238335 -  AUC val = 0.9187706138341731
#
# Inicio de iteracion 1265. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:41:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Fin de iteracion 1265. Parametro nrounds = 100, parametro eta = 0.99, parametro gamma = 1, parametro max_depth = 20, parametro min_child_weight = 20, parametro subsample = 1, parametro colsample_bytree = 1, parametro num_parallel_tree = 20, parametro lambda = 1, parametro alpha = 1. AUC train = 0.9995794735230298 -  AUC val = 0.9239950755840587

# %% [markdown]
# Veamos los resultados.

# %%
grid_results
# Out:
#                     model                                             params  \
# 0     Logistic Regression         {'regularization': ['l1'], 'penalty': [1]}
# 1     Logistic Regression        {'regularization': ['l1'], 'penalty': [10]}
# 2     Logistic Regression       {'regularization': ['l1'], 'penalty': [100]}
# 3     Logistic Regression         {'regularization': ['l2'], 'penalty': [1]}
# 4     Logistic Regression        {'regularization': ['l2'], 'penalty': [10]}
# ...                   ...                                                ...
# 1260              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1261              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1262              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1263              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
# 1264              xgboost  {'nrounds': [100], 'eta': [0.99], 'gamma': [1]...
#
#       auc_train   auc_val
# 0      0.940573  0.938050
# 1      0.940520  0.937936
# 2      0.940513  0.937799
# 3      0.940531  0.938426
# 4      0.940515  0.938951
# ...         ...       ...
# 1260   0.999579  0.923994
# 1261   0.999807  0.926567
# 1262   0.999431  0.922814
# 1263   0.999721  0.918771
# 1264   0.999579  0.923995
#
# [1265 rows x 4 columns]

# %% [markdown]
# Vamos a analizar el mejor resultado para cada familia de modelos.

# %%
grid_results.groupby(['model'], sort=False)['auc_val'].max().sort_values()
# Out:
# model
# decision tree          0.937351
# Logistic Regression    0.938951
# SVM                    0.939226
# random forest          0.943195
# xgboost                0.945624
# Name: auc_val, dtype: float64

# %% [markdown]
# Nos quedamos con la mejor combinación de familia de modelos + hiperparámetros.

# %%
best_params = grid_results.iloc[grid_results['auc_val'].idxmax()]

# %% [markdown]
# Juntamos validación y train para entrenar el modelo final.

# %%
print('Train data size = ' + str(X_train.shape))
print('Train target size = ' + str(y_train.shape))
print('Validation data size = ' + str(X_val.shape))
print('Validation target size = ' + str(y_val.shape))

# Combinar train y validación
X_train = pd.concat((X_train,X_val), axis = 0)
y_train = np.concatenate((y_train, y_val), axis = 0)

del X_val, y_val

print('Train data size = ' + str(X_train.shape))
print('Train target size = ' + str(y_train.shape))
# Out:
# Train data size = (22894, 22)
# Train target size = (22894,)
# Validation data size = (4905, 22)
# Validation target size = (4905,)
# Train data size = (27799, 22)
# Train target size = (27799,)

# %% [markdown]
# Y ahora entrenamos el modelo final.

# %%
# Logistic Regression
if best_params['model'] == 'logistic regression':       

    # Entrenar modelo
    if best_params['params']['regularization'] == 'l1':
        model = LogisticRegression(penalty = best_params['params']['regularization'][0], solver = 'liblinear', C = best_params['params']['penalty'][0], random_state = random_state)
    else:
        model = LogisticRegression(penalty = best_params['params']['regularization'][0],solver = 'lbfgs', C = best_params['params']['penalty'][0], random_state = random_state)


# SVM
elif best_params['model'] == 'SVM':

    model = SVC(C = best_params['params']['C'][0], gamma = best_params['params']['gamma_kernel'][0], probability = True, 
                random_state = random_state)             


# Decision Tree
elif best_params['model'] == 'decision tree':
    model = DecisionTreeClassifier(max_depth = int(best_params['params']['max_depth'][0]),
                                                  min_samples_split = int(best_params['params']['min_samples_split'][0]),
                                                  min_samples_leaf = int(best_params['params']['min_samples_leaf'][0]),
                                                  max_features = int(best_params['params']['max_features'][0]), 
                                   random_state = random_state)


# Random Forest
elif best_params['model'] == 'random forest':
    model = RandomForestClassifier(n_estimators = int(best_params['params']['n_trees'][0]),
                                                      max_depth = int(best_params['params']['max_depth'][0]),
                                                      min_samples_split = int(best_params['params']['min_samples_split'][0]),
                                                      min_samples_leaf = int(best_params['params']['min_samples_leaf'][0]),
                                                      max_features = int(best_params['params']['max_features'][0]), 
                                                      random_state = random_state)

# XGBOOST
elif best_params['model'] == 'xgboost':
    model = XGBClassifier(nthread = nthread, 
                                                              scale_pos_weight = scale_pos_weight,
                                                              random_state = random_state,
                                                              n_estimators = int(best_params['params']['nrounds'][0]), 
                                                              learning_rate = best_params['params']['eta'][0], 
                                                              gamma = best_params['params']['gamma'][0],
                                                              max_depth = int(best_params['params']['max_depth'][0]),
                                                              min_child_weight = best_params['params']['min_child_weight'][0],
                                                              subsample = best_params['params']['subsample'][0],
                                                              colsample_bytree = best_params['params']['colsample_bytree'][0],
                                                              num_parallel_tree  = int(best_params['params']['num_parallel_tree'][0]),
                                                              reg_lambda = best_params['params']['lamda'][0],
                                                              reg_alpha = best_params['params']['alpha'][0])

# Entrenar modelo
model.fit(X_train, np.array(y_train))

# Generar predicciones
pred_train_p = model.predict_proba(X_train)
pred_test_p = model.predict_proba(X_test)

# Calcular métricas de evaluación
auc_train = metric(y_train, pred_train_p[:, 1])
auc_test = metric(y_test, pred_test_p[:, 1]) 

results = pd.DataFrame()
results = results.append(pd.DataFrame(data={'model':best_params['model'],'auc_train':[auc_train],'auc_test':[auc_test]}, columns=['model',  'auc_train', 'auc_test']), ignore_index=True)
# Out:
# [14:41:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# c:\users\juanl\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
results
# Out:
#      model  auc_train  auc_test
# 0  xgboost   0.961011  0.937501
