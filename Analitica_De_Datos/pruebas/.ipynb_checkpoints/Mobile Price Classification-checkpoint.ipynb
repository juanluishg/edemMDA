# %% [markdown]
# # Mobile Price Classification

# %% [markdown]
# https://www.kaggle.com/iabhishekofficial/mobile-price-classification

# %%
#!pip install pandas
#!pip install scikit-learn
#!pip install sweetviz
# !pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\juanl\appdata\roaming\python\python39\site-packages (7.6.3)
# Requirement already satisfied: traitlets>=4.3.1 in c:\python39\lib\site-packages (from ipywidgets) (5.0.5)
# Requirement already satisfied: ipython>=4.0.0 in c:\python39\lib\site-packages (from ipywidgets) (7.19.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\juanl\appdata\roaming\python\python39\site-packages (from ipywidgets) (5.4.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\python39\lib\site-packages (from ipywidgets) (5.1.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\python39\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\python39\lib\site-packages (from ipywidgets) (3.5.1)
# Requirement already satisfied: tornado>=4.2 in c:\users\juanl\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: jupyter-client in c:\users\juanl\appdata\roaming\python\python39\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.7)
# Requirement already satisfied: jedi>=0.10 in c:\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.17.2)
# Requirement already satisfied: colorama in c:\users\juanl\appdata\roaming\python\python39\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.8)
# Requirement already satisfied: backcall in c:\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pygments in c:\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.7.3)
# Requirement already satisfied: pickleshare in c:\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (49.2.1)
# Requirement already satisfied: decorator in c:\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\python39\lib\site-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets) (0.7.1)
# Requirement already satisfied: ipython-genutils in c:\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\juanl\appdata\roaming\python\python39\site-packages (from nbformat>=4.2.0->ipywidgets) (4.7.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets) (3.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\juanl\appdata\roaming\python\python39\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\python39\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets) (20.3.0)
# Requirement already satisfied: wcwidth in c:\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\python39\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets) (6.2.0)
# Requirement already satisfied: argon2-cffi in c:\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.1.0)
# Requirement already satisfied: nbconvert in c:\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (6.0.7)
# Requirement already satisfied: pyzmq>=17 in c:\users\juanl\appdata\roaming\python\python39\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.0.0)
# Requirement already satisfied: jinja2 in c:\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.11.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.9.2)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\python39\lib\site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\juanl\appdata\roaming\python\python39\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets) (300)
# Requirement already satisfied: pywinpty>=0.5 in c:\python39\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\python39\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.14.5)
# Requirement already satisfied: pycparser in c:\python39\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\python39\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.1.1)
# Requirement already satisfied: defusedxml in c:\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.6.0)
# Requirement already satisfied: bleach in c:\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (3.3.0)
# Requirement already satisfied: jupyterlab-pygments in c:\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.2)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.3)
# Requirement already satisfied: testpath in c:\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\python39\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.8.4)
# Requirement already satisfied: nest-asyncio in c:\python39\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.5.1)
# Requirement already satisfied: async-generator in c:\python39\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (1.10)
# Requirement already satisfied: webencodings in c:\python39\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in c:\python39\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (20.9)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\python39\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets) (2.4.7)

# %%
#Import libraries
import pandas as pd
import numpy
import math
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
import sweetviz as sw

# %%
raw_train = pd.read_csv('train.csv')
raw_test = pd.read_csv('test.csv')

# %%
raw_train.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
raw_test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
#
# [5 rows x 21 columns]

# %%
raw_all = pd.concat([raw_train, raw_test])

# %%
raw_all.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_width   ram  sc_h  sc_w  talk_time  three_g  \
# 0        188        2  ...       756  2549     9     7         19        0
# 1        136        3  ...      1988  2631    17     3          7        1
# 2        145        5  ...      1716  2603    11     2          9        1
# 3        131        6  ...      1786  2769    16     8         11        1
# 4        141        2  ...      1212  1411     8     2         15        1
#
#    touch_screen  wifi  price_range  id
# 0             0     1          1.0 NaN
# 1             1     0          2.0 NaN
# 2             1     0          2.0 NaN
# 3             0     0          2.0 NaN
# 4             1     0          1.0 NaN
#
# [5 rows x 22 columns]

# %%
raw_all = raw_all.reset_index()
raw_all = raw_all.drop(['id','index'], axis=1)

# %%
raw_all.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1          1.0
# 1        1             1     0          2.0
# 2        1             1     0          2.0
# 3        1             0     0          2.0
# 4        1             1     0          1.0
#
# [5 rows x 21 columns]

# %%
plt.hist(raw_all.n_cores, edgeColor='black')
# Out:
# <ipython-input-13-e1b7fdbc97e7>:1: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.hist(raw_all.n_cores, edgeColor='Black')
# (array([380., 381., 373.,   0., 416., 376.,   0., 331., 366., 377.]),
#  array([1. , 1.7, 2.4, 3.1, 3.8, 4.5, 5.2, 5.9, 6.6, 7.3, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
my_report = sw.analyze(raw_all)
my_report.show_html()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-340bb8480afb> in <module>
# ----> 1 my_report = sw.analyze(raw_all)
#       2 my_report.show_html()
#
# c:\python39\lib\site-packages\sweetviz\sv_public.py in analyze(source, target_feat, feat_cfg, pairwise_analysis)
#      10             feat_cfg: FeatureConfig = None,
#      11             pairwise_analysis: str = 'auto'):
# ---> 12     report = sweetviz.DataframeReport(source, target_feat, None,
#      13                                       pairwise_analysis, feat_cfg)
#      14     return report
#
# c:\python39\lib\site-packages\sweetviz\dataframe_report.py in __init__(self, source, target_feature_name, compare, pairwise_analysis, fc)
#     118                             + number_features + (0 if target_feature_name is not None else 0)
#     119
# --> 120         self.progress_bar = tqdm(total=progress_chunks, bar_format= \
#     121                 '{desc:45}|{bar}| [{percentage:3.0f}%]   {elapsed} -> ({remaining} left)', \
#     122                 ascii=False, dynamic_ncols=True, position=0, leave= True)
#
# c:\python39\lib\site-packages\tqdm\notebook.py in __init__(self, *args, **kwargs)
#     238         unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     239         total = self.total * unit_scale if self.total else self.total
# --> 240         self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     241         self.container.pbar = self
#     242         if display_here:
#
# c:\python39\lib\site-packages\tqdm\notebook.py in status_printer(_, total, desc, ncols)
#     115         # Prepare IPython progress bar
#     116         if IProgress is None:  # #187 #451 #558 #872
# --> 117             raise ImportError(
#     118                 "IProgress not found. Please update jupyter and ipywidgets."
#     119                 " See https://ipywidgets.readthedocs.io/en/stable"
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
