# %% [markdown]
# ## Instalacion de Paquetes Necesarios

# %%
# cargar los archivos del drive!
# !sudo apt-get install tesseract-ocr
# !pip install pytesseract
# !pip uninstall --yes scipy
# !pip install scipy==1.1.0
# !pip install opencv-python
# !pip install matplotlib
# Out:
# [sudo] password for juanluishg:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytesseract in /home/juanluishg/.local/lib/python3.7/site-packages (0.3.7)
# Requirement already satisfied: Pillow in /home/juanluishg/.local/lib/python3.7/site-packages (from pytesseract) (8.2.0)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Found existing installation: scipy 1.1.0
# Uninstalling scipy-1.1.0:
#   Successfully uninstalled scipy-1.1.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy==1.1.0
#   Using cached scipy-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (31.2 MB)
# Requirement already satisfied: numpy>=1.8.2 in /home/juanluishg/.local/lib/python3.7/site-packages (from scipy==1.1.0) (1.18.5)
# Installing collected packages: scipy
# Successfully installed scipy-1.1.0
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /home/juanluishg/.local/lib/python3.7/site-packages (4.5.2.52)
# Requirement already satisfied: numpy>=1.14.5 in /home/juanluishg/.local/lib/python3.7/site-packages (from opencv-python) (1.18.5)
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 712 kB/s eta 0:00:01
# Requirement already satisfied: pillow>=6.2.0 in /home/juanluishg/.local/lib/python3.7/site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/juanluishg/.local/lib/python3.7/site-packages (from matplotlib) (2.8.1)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pyparsing>=2.2.1
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16 in /home/juanluishg/.local/lib/python3.7/site-packages (from matplotlib) (1.18.5)
# Requirement already satisfied: six in /home/juanluishg/.local/lib/python3.7/site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Installing collected packages: pyparsing, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 pyparsing-2.4.7
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ## Simple OCR

# %%
# pytesseract es una libreria de Google que contiene un modelo de OCR
import pytesseract
# usaremos OpenCV, libreria principal para trabajar con imagenes
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# decodificamos la imagen y la cargamos en memoria
# PATH: ./drive/MyDrive/EDEM_Master/...
image = cv2.imread("OCR/test_OCR_pt1.png")
# cambiamos el orden de los canales para que Tesseract los pueda leer
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# OpenCV devuelve un objeto de tipo Numpy
print(type(image), image.shape)
plt.imshow(image)
# Out:
# <class 'numpy.ndarray'> (1029, 1242, 3)

# %%
print(pytesseract.image_to_string(image))
# Out:
# SCENE FROM “DAN'L DRUCE.”
#
# This interesting domestic drama, by Mr. W. 8. Gilbert,
# has continued to engage the sympathies of a nightly
# sufficient audience at the Haymarket Theatre, where it
# has now been represented more than sixty times. Its
# subject and character were described by us, in the
# ordinary report of theatrical novelties, about two months
# ago. Our readers will probably not need to be reminded
# that the hero of the story, Dan’l Druce, the blacksmith,
# is a solitary recluse dwelling on the coast of Norfolk,
# where his lone cottage is visited by fugitives from party
# v.ngeance during the civil wars of the Commonwealth.
# Ifis hoard of money is stolen; but a different sort of
# treasure, a helpless female infant; is left by some mys-
# terious agency, and may be accepted, as in George
# Eliot’s tale of “Silas Marner,’ for a Divine gift to the
# gad-hearted misanthrope, far better than riches. . In
# this spirit, at least, he is content to receive the precious
# human charge; and so to those who would remove it
# from his home, Dan’l Druce here makes answer with
# the solemn exclamation, “Touch not the Lord’s gift!”
# This character is well acted by Mr. Hermann Vezin.

# %%
# decodificamos la imagen y la cargamos en memoria
image = cv2.imread("OCR/test_OCR_pt2.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# OpenCV devuelve un objeto de tipo Numpy
print(type(image), image.shape)
plt.imshow(image)
# Out:
# <class 'numpy.ndarray'> (739, 720, 3)

# %%
# sacamos ahora las cajas de deteccion de texto para saber la localizacion
config = ("-l eng --oem 1 --psm 7")
box_data = pytesseract.image_to_boxes(image)
print(box_data)
# Out:
# P 189 349 217 419 0
# a 217 349 236 419 0
# t 253 348 280 395 0
# i 289 348 324 417 0
# e 333 348 360 395 0
# n 360 348 371 395 0
# c 396 349 422 395 0
# e 432 348 463 395 0
# . 468 348 526 395 0

# %%
# copiamos la imagen para poder dibujar sobre ella sin modificar la original
canvas = image.copy()

x1 = box_data.split('\n')[0].split(' ')[1]
y1 = box_data.split('\n')[0].split(' ')[2]
x2 = box_data.split('\n')[-2].split(' ')[3]
y2 = box_data.split('\n')[-2].split(' ')[4]
cv2.rectangle(canvas, (int(x1), int(y1)), (int(x2), int(y2)), (255, 0, 0), 2)


# iteramos sobre cada linea
for c in box_data.split('\n')[:-1]:
  # separamos por espacios y almacenamos en variables
  _, x1, y1, x2, y2, _, = c.split(' ')
  # dibujamos los cuadrados sobre la imagen usando una funcion de OpenCV
  cv2.rectangle(canvas, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)


# mostramos la imagen
plt.figure(figsize=(7, 7))
plt.imshow(canvas)

# %%
# ahora un ejemplo mas complicado
image = cv2.imread('OCR/test_OCR_pt3.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
# tesseract ocr no saca nada...
print(pytesseract.image_to_string(image))
# Out:
#
#
# rawpixel”

# %% [markdown]
# ## Ejercicio 1
# ### Extraccion de Partes de un Form

# %%
# cargamos la imagen de un form simple 
image = cv2.imread('OCR/ej_OCR_1.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image)

# %%
# El ejercicio consistira en sacar la informacion de: NOMBRE DEL APLICANTE,
# NUMERO DE TELEFONO Y RESIDUAL PRESSURE (+ QUE UNIDADES USA (EXTRA)).
# TIPS: Sacar primero el texto de la imagen y ver como se separan los caracteres,
# suponer que siempre el nombre (siempre nobre + 1 apellido) va a estar detras de "Name", etc...
# FUNCIONES UTILES PARA GOOGLEAR: "split()", "index()", "filter()", "join()"

# %%
# TO-DO
text = pytesseract.image_to_string(image) 
print(text)
# Out:
#
#
#
#
#
#
# TEST LOCATION
#
# ‘Address/Location Description: 814 Cemetery St. Saint Albans, NY 11412
# Test Hydrant Facility ID WHYD 29
#
# Flow Hydrant Facility ID WHYD 5
#
#
#
# APPLICATION INFORMATION
#
# Name John Doe
#
# Address 257 Manhattan Drive Brainerd MN 56401 NY 34512345
# Contact Person John Doe Phone (541) 754-3010,
#
# SYSTEM INFORMATION
#
#
#
# Test Date 2020-04-14 Time of Test 02:09:06
#
# Nearest Elevated Tank A water tower Test Hydrant Elevation 400
#
# Main Size 24 Pressure Zone 20
#
# Tank Hydraulic Grade 24 Use 201 below pressure zone (tank overflow) for design”
# Pump Info 12 Theoretical Pressure 300
#
# RESULTS
#
# Static Pressure 260 psi Number of Outlets Flowing 12
#
# Residual Pressure 100 psi Flow Hydrant Discharge Pressure 400 psi
#
# Outlet Diameter 250 inches Volume of Discharge 16 gpm

# %%
paragraph = text.split('\n')
for i in paragraph:
    if i.startswith('Name'):
        name = i.split(' ')[1]
        surname = i.split(' ')[2]
    if i.find('Phone') != -1:
        phone = i.split('Phone')[1].strip().replace(',', '')
    if i.find('Residual Pressure') != -1:
        residual = i.split(' ')[2]
        metric = i.split(' ')[3]

# %%
print('{} {} with phone {}\nResidual Pressure test: {} {}'.format(name, surname, phone, residual, metric))
# Out:
# John Doe with phone (541) 754-3010
# Residual Pressure test: 100 psi
