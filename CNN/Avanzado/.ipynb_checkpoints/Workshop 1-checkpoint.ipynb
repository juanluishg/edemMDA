#  PosixPath('/root/.fastai/data/cifar100/test/household_electrical_devices'),
#  PosixPath('/root/.fastai/data/cifar100/test/large_omnivores_and_herbivores'),
#  PosixPath('/root/.fastai/data/cifar100/test/large_natural_outdoor_scenes'),
#  PosixPath('/root/.fastai/data/cifar100/test/household_furniture'),
#  PosixPath('/root/.fastai/data/cifar100/test/medium_mammals'),
#  PosixPath('/root/.fastai/data/cifar100/test/small_mammals'),
#  PosixPath('/root/.fastai/data/cifar100/test/vehicles_2'),
#  PosixPath('/root/.fastai/data/cifar100/test/aquatic_mammals')]

# %%
# Open image with fastai helper function
img = open_image('/root/.fastai/data/cifar100/train/reptiles/dinosaur/stegosaurus_s_001202.png')

# %%
img.show()

# %%
img.shape
# Out:
# torch.Size([3, 32, 32])

# %% [markdown]
# # 1. Load and explore data

# %%
# Load data
batch_size = 256
size = 32
data = ImageDataBunch.from_folder(path=path, train="train", test="test", 
                                  valid_pct=0.2, 
                                  ds_tfms=get_transforms(), size=size, 
                                  bs=batch_size
                                  ).normalize(imagenet_stats)

# %% [markdown]
# You can check this [link](https://docs.fast.ai/vision.data.html) to learn many more options to load data

# %%
# Show classes
data.classes
# Out:
# ['apple',
#  'aquarium_fish',
#  'baby',
#  'bear',
#  'beaver',
#  'bed',
#  'bee',
#  'beetle',
#  'bicycle',
#  'bottle',
#  'bowl',
#  'boy',
#  'bridge',
#  'bus',
#  'butterfly',
#  'camel',
#  'can',
#  'castle',
#  'caterpillar',
#  'cattle',
#  'chair',
#  'chimpanzee',
#  'clock',
#  'cloud',
#  'cockroach',
#  'couch',
#  'crab',
#  'crocodile',
#  'cup',
#  'dinosaur',
#  'dolphin',
#  'elephant',
#  'flatfish',
#  'forest',
#  'fox',
#  'girl',
#  'hamster',
#  'house',
#  'kangaroo',
#  'keyboard',
#  'lamp',
#  'lawn_mower',
#  'leopard',
#  'lion',
#  'lizard',
#  'lobster',
#  'man',
#  'maple_tree',
#  'motorcycle',
#  'mountain',
#  'mouse',
#  'mushroom',
#  'oak_tree',
#  'orange',
#  'orchid',
#  'otter',
#  'palm_tree',
#  'pear',
#  'pickup_truck',
#  'pine_tree',
#  'plain',
#  'plate',
#  'poppy',
#  'porcupine',
#  'possum',
#  'rabbit',
#  'raccoon',
#  'ray',
#  'road',
#  'rocket',
#  'rose',
#  'sea',
#  'seal',
#  'shark',
#  'shrew',
#  'skunk',
#  'skyscraper',
#  'snail',
#  'snake',
#  'spider',
#  'squirrel',
#  'streetcar',
#  'sunflower',
#  'sweet_pepper',
#  'table',
#  'tank',
#  'telephone',
#  'television',
#  'tiger',
#  'tractor',
#  'train',
#  'trout',
#  'tulip',
#  'turtle',
#  'wardrobe',
#  'whale',
#  'willow_tree',
#  'wolf',
#  'woman',
#  'worm']

# %%
print(len(data.classes))
# Out:
# 100

# %%
# Show samples of data
data.show_batch(rows=3, figsize=(7,6))

# %% [markdown]
# # 2.   Train the model

# %% [markdown]
# ## 32x32

# %%
# Initialize learner
learn = cnn_learner(data, models.resnet18, metrics=accuracy)

# %% [markdown]
# You can check this [link](https://docs.fast.ai/vision.models.html) to learn the different state of the art models implemented in fastai

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=100, bias=True)
#   )
# )

# %%
# Find optimum learning rate
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='90' class='' max='156', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       57.69% [90/156 00:27<00:20 12.8040]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# Set learning rate
lr = 1e-2

# %%
# Train 5 epochs
learn.fit_one_cycle(5, max_lr=slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.119903</td>
#       <td>3.472095</td>
#       <td>0.205700</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.335913</td>
#       <td>2.943866</td>
#       <td>0.267600</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.926814</td>
#       <td>2.693204</td>
#       <td>0.310800</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.747998</td>
#       <td>2.568961</td>
#       <td>0.336000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.638047</td>
#       <td>2.550896</td>
#       <td>0.341000</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save model
learn.save("score-3410")

# %%
# Unfreeze conv layers
learn.unfreeze()

# %%
# Find learning rate
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='88' class='' max='156', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       56.41% [88/156 00:26<00:20 8.0780]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# Set learning rate
lr = 5e-4

# %%
# Train 5 epochs
learn.fit_one_cycle(5, max_lr=slice(lr/100,lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.549655</td>
#       <td>2.461352</td>
#       <td>0.357100</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.404824</td>
#       <td>2.307838</td>
#       <td>0.389400</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.256045</td>
#       <td>2.217715</td>
#       <td>0.411100</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.166090</td>
#       <td>2.171139</td>
#       <td>0.422800</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.114076</td>
#       <td>2.165396</td>
#       <td>0.423600</td>
#       <td>00:51</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save model
learn.save("score-4236")

# %% [markdown]
# ## 128x128

# %%
# Load data
batch_size = 64
size = 128
data = ImageDataBunch.from_folder(path=path, train="train", test="test", 
                                  valid_pct=0.2, 
                                  ds_tfms=get_transforms(), size=size, 
                                  bs=batch_size
                                  ).normalize(imagenet_stats)

# %%
# Configure learner with new data and freeze conv layers
learn.data = data
learn.freeze()

# %%
# Find learning rate
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='88' class='' max='625', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       14.08% [88/625 00:14<01:26 9.3335]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# Set learning rate
lr = 1e-2

# %%
# Train 5 epochs
learn.fit_one_cycle(5, max_lr=slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.832123</td>
#       <td>1.449993</td>
#       <td>0.577100</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.623168</td>
#       <td>1.253491</td>
#       <td>0.629600</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.373911</td>
#       <td>1.083378</td>
#       <td>0.676800</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.205705</td>
#       <td>0.984446</td>
#       <td>0.704300</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.100975</td>
#       <td>0.961671</td>
#       <td>0.709300</td>
#       <td>01:50</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save model
learn.save("score-7093")

# %%
# Unfreeze conv layers
learn.unfreeze()

# %%
# Find learning rate
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='84' class='' max='625', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       13.44% [84/625 00:13<01:29 4.3139]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# Set learning rate
lr = 1e-4

# %%
# Train 5 epochs
learn.fit_one_cycle(5, max_lr=slice(lr/100,lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.150248</td>
#       <td>0.974993</td>
#       <td>0.707000</td>
#       <td>01:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.041342</td>
#       <td>0.905688</td>
#       <td>0.729200</td>
#       <td>01:53</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.008493</td>
#       <td>0.880130</td>
#       <td>0.733600</td>
#       <td>01:53</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.949288</td>
#       <td>0.864403</td>
#       <td>0.739200</td>
#       <td>01:52</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.943572</td>
#       <td>0.864683</td>
#       <td>0.737800</td>
#       <td>01:53</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save model
learn.save("score-7378")

# %% [markdown]
# # 224x224

# %%
# Load data
batch_size = 32
size = 224
data = ImageDataBunch.from_folder(path=path, train="train", test="test", 
                                  valid_pct=0.2, 
                                  ds_tfms=get_transforms(), size=size, 
                                  bs=batch_size
                                  ).normalize(imagenet_stats)

# %%
# Configure learner with new data and freeze conv layers
learn.data = data
learn.freeze()

# %%
# Find learning rate
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='85' class='' max='1250', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.80% [85/1250 00:14<03:21 4.3717]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# Set learning rate
lr = 5e-3

# %%
# Train 5 epochs
learn.fit_one_cycle(5, max_lr=slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.314839</td>
#       <td>0.889715</td>
#       <td>0.734900</td>
#       <td>03:57</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.302426</td>
#       <td>0.872548</td>
#       <td>0.737900</td>
#       <td>03:57</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.161859</td>
#       <td>0.826766</td>
#       <td>0.754500</td>
#       <td>03:57</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.077084</td>
#       <td>0.787635</td>
#       <td>0.762500</td>
#       <td>03:57</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.006067</td>
#       <td>0.784034</td>
#       <td>0.766500</td>
#       <td>03:57</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save model
learn.save("score-7665")

# %%
# Unfreeze conv layers
learn.unfreeze()

# %%
# Find learning rate
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='76' class='' max='1250', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.08% [76/1250 00:13<03:34 3.0848]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# Set learning rate
lr = 1e-4

# %%
# Train 5 epochs
learn.fit_one_cycle(5, max_lr=slice(lr/100,lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.010176</td>
#       <td>0.760091</td>
#       <td>0.772800</td>
#       <td>04:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.937335</td>
#       <td>0.741710</td>
#       <td>0.776600</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.933946</td>
#       <td>0.721253</td>
#       <td>0.783000</td>
#       <td>04:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.865901</td>
#       <td>0.713224</td>
#       <td>0.786000</td>
#       <td>04:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.815792</td>
#       <td>0.707143</td>
#       <td>0.789800</td>
#       <td>04:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save model
learn.save("score-7898")

# %% [markdown]
# # 3.   Evaluate results

# %%
# Mostrar muestras peor classificadas
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_top_losses(9, figsize=(15,11))

# %%
# Show confusion matrix
interp.plot_confusion_matrix(figsize=(30,30), dpi=60)

# %%
# Show most confused classes
interp.most_confused(min_val=2)
# Out:
# [('maple_tree', 'oak_tree', 26),
#  ('pine_tree', 'oak_tree', 26),
#  ('girl', 'boy', 20),
#  ('bowl', 'plate', 18),
#  ('willow_tree', 'oak_tree', 17),
#  ('girl', 'woman', 16),
#  ('woman', 'boy', 14),
#  ('flatfish', 'ray', 13),
#  ('tulip', 'poppy', 13),
#  ('baby', 'girl', 12),
#  ('beetle', 'cockroach', 11),
#  ('boy', 'baby', 11),
#  ('forest', 'willow_tree', 11),
#  ('pine_tree', 'maple_tree', 11),
#  ('poppy', 'tulip', 11),
#  ('snake', 'worm', 11),
#  ('willow_tree', 'maple_tree', 11),
#  ('woman', 'girl', 11),
#  ('boy', 'man', 10),
#  ('cloud', 'sea', 10),
#  ('couch', 'chair', 10),
#  ('dolphin', 'whale', 10),
#  ('man', 'boy', 10),
#  ('mouse', 'hamster', 10),
#  ('streetcar', 'bus', 10),
#  ('whale', 'dolphin', 10),
#  ('bus', 'streetcar', 9),
#  ('dolphin', 'shark', 9),
#  ('girl', 'baby', 9),
#  ('mouse', 'shrew', 9),
#  ('oak_tree', 'maple_tree', 9),
#  ('plain', 'sea', 9),
#  ('seal', 'otter', 9),
#  ('worm', 'snake', 9),
#  ('baby', 'boy', 8),
#  ('beaver', 'porcupine', 8),
#  ('man', 'woman', 8),
#  ('sweet_pepper', 'tulip', 8),
#  ('train', 'streetcar', 8),
#  ('lizard', 'crocodile', 7),
#  ('pine_tree', 'palm_tree', 7),
#  ('plate', 'clock', 7),
#  ('shark', 'trout', 7),
#  ('table', 'bed', 7),
#  ('tiger', 'leopard', 7),
#  ('tulip', 'rose', 7),
#  ('woman', 'man', 7),
#  ('bed', 'couch', 6),
#  ('bed', 'table', 6),
#  ('lamp', 'cup', 6),
#  ('mouse', 'possum', 6),
#  ('otter', 'seal', 6),
#  ('pear', 'apple', 6),
#  ('rose', 'tulip', 6),
#  ('seal', 'shark', 6),
#  ('shark', 'dolphin', 6),
#  ('shrew', 'crocodile', 6),
#  ('shrew', 'mouse', 6),
#  ('spider', 'beetle', 6),
#  ('tulip', 'orchid', 6),
#  ('bear', 'seal', 5),
#  ('beaver', 'shrew', 5),
#  ('bicycle', 'motorcycle', 5),
#  ('bridge', 'skyscraper', 5),
#  ('camel', 'cattle', 5),
#  ('can', 'bowl', 5),
#  ('crab', 'lobster', 5),
#  ('cup', 'bowl', 5),
#  ('hamster', 'mouse', 5),
#  ('hamster', 'possum', 5),
#  ('leopard', 'lion', 5),
#  ('leopard', 'tiger', 5),
#  ('man', 'girl', 5),
#  ('motorcycle', 'bicycle', 5),
#  ('otter', 'beaver', 5),
#  ('poppy', 'rose', 5),
#  ('possum', 'mouse', 5),
#  ('ray', 'shark', 5),
#  ('rose', 'orchid', 5),
#  ('seal', 'ray', 5),
#  ('shark', 'ray', 5),
#  ('skyscraper', 'rocket', 5),
#  ('tractor', 'lawn_mower', 5),
#  ('turtle', 'flatfish', 5),
#  ('baby', 'woman', 4),
#  ('bear', 'beaver', 4),
#  ('beaver', 'otter', 4),
#  ('bottle', 'can', 4),
#  ('boy', 'girl', 4),
#  ('caterpillar', 'snake', 4),
#  ('clock', 'telephone', 4),
#  ('cloud', 'plain', 4),
#  ('couch', 'bed', 4),
#  ('crab', 'lizard', 4),
#  ('crocodile', 'otter', 4),
#  ('forest', 'maple_tree', 4),
#  ('fox', 'cattle', 4),
#  ('girl', 'man', 4),
#  ('house', 'bridge', 4),
#  ('house', 'castle', 4),
#  ('lamp', 'mushroom', 4),
#  ('lamp', 'table', 4),
#  ('lizard', 'caterpillar', 4),
#  ('lizard', 'shrew', 4),
#  ('lobster', 'crab', 4),
#  ('maple_tree', 'willow_tree', 4),
#  ('otter', 'camel', 4),
#  ('plate', 'bowl', 4),
#  ('rabbit', 'kangaroo', 4),
#  ('ray', 'flatfish', 4),
#  ('rose', 'poppy', 4),
#  ('sea', 'cloud', 4),
#  ('seal', 'bear', 4),
#  ('seal', 'beaver', 4),
#  ('shrew', 'beaver', 4),
#  ('shrew', 'porcupine', 4),
#  ('squirrel', 'mouse', 4),
#  ('trout', 'shark', 4),
#  ('willow_tree', 'forest', 4),
#  ('willow_tree', 'pine_tree', 4),
#  ('beaver', 'seal', 3),
#  ('bed', 'chair', 3),
#  ('bee', 'beetle', 3),
#  ('beetle', 'butterfly', 3),
#  ('bowl', 'clock', 3),
#  ('bowl', 'cup', 3),
#  ('boy', 'woman', 3),
#  ('bridge', 'castle', 3),
#  ('bus', 'pickup_truck', 3),
#  ('castle', 'house', 3),
#  ('chimpanzee', 'elephant', 3),
#  ('crab', 'plate', 3),
#  ('crab', 'turtle', 3),
#  ('crocodile', 'lizard', 3),
#  ('dolphin', 'seal', 3),
#  ('elephant', 'cattle', 3),
#  ('flatfish', 'trout', 3),
#  ('kangaroo', 'raccoon', 3),
#  ('lamp', 'telephone', 3),
#  ('lion', 'tiger', 3),
#  ('lizard', 'snake', 3),
#  ('lizard', 'turtle', 3),
#  ('mountain', 'sea', 3),
#  ('mouse', 'beaver', 3),
#  ('mouse', 'rabbit', 3),
#  ('orchid', 'rose', 3),
#  ('otter', 'bear', 3),
#  ('otter', 'dolphin', 3),
#  ('otter', 'whale', 3),
#  ('pear', 'orange', 3),
#  ('pine_tree', 'willow_tree', 3),
#  ('plain', 'cloud', 3),
#  ('plain', 'road', 3),
#  ('poppy', 'butterfly', 3),
#  ('porcupine', 'beaver', 3),
#  ('porcupine', 'possum', 3),
#  ('rabbit', 'hamster', 3),
#  ('rabbit', 'possum', 3),
#  ('raccoon', 'possum', 3),
#  ('raccoon', 'wolf', 3),
#  ('ray', 'seal', 3),
#  ('rocket', 'skyscraper', 3),
#  ('seal', 'dolphin', 3),
#  ('seal', 'whale', 3),
#  ('shark', 'whale', 3),
#  ('snake', 'butterfly', 3),
#  ('squirrel', 'possum', 3),
#  ('squirrel', 'shrew', 3),
#  ('streetcar', 'road', 3),
#  ('streetcar', 'train', 3),
#  ('tiger', 'fox', 3),
#  ('train', 'tank', 3),
#  ('train', 'tractor', 3),
#  ('trout', 'flatfish', 3),
#  ('tulip', 'sweet_pepper', 3),
#  ('turtle', 'crocodile', 3),
#  ('turtle', 'snail', 3),
#  ('whale', 'shark', 3),
#  ('bear', 'camel', 2),
#  ('bear', 'leopard', 2),
#  ('bear', 'mouse', 2),
#  ('beaver', 'bear', 2),
#  ('beaver', 'lion', 2),
#  ('beaver', 'mouse', 2),
#  ('bee', 'caterpillar', 2),
#  ('bee', 'lobster', 2),
#  ('beetle', 'bee', 2),
#  ('beetle', 'snail', 2),
#  ('beetle', 'spider', 2),
#  ('bottle', 'lamp', 2),
#  ('bowl', 'can', 2),
#  ('bowl', 'mushroom', 2),
#  ('bowl', 'sweet_pepper', 2),
#  ('bowl', 'telephone', 2),
#  ('boy', 'chimpanzee', 2),
#  ('bridge', 'house', 2),
#  ('bridge', 'road', 2),
#  ('butterfly', 'caterpillar', 2),
#  ('butterfly', 'orchid', 2),
#  ('butterfly', 'spider', 2),
#  ('can', 'bottle', 2),
#  ('can', 'cup', 2),
#  ('castle', 'bridge', 2),
#  ('castle', 'mountain', 2),
#  ('caterpillar', 'lizard', 2),
#  ('caterpillar', 'shrew', 2),
#  ('caterpillar', 'worm', 2),
#  ('cattle', 'elephant', 2),
#  ('chair', 'bed', 2),
#  ('chair', 'couch', 2),
#  ('chimpanzee', 'bear', 2),
#  ('clock', 'lamp', 2),
#  ('clock', 'plate', 2),
#  ('clock', 'television', 2),
#  ('cloud', 'ray', 2),
#  ('cockroach', 'beetle', 2),
#  ('couch', 'lamp', 2),
#  ('couch', 'television', 2),
#  ('crab', 'cockroach', 2),
#  ('crab', 'porcupine', 2),
#  ('crocodile', 'beaver', 2),
#  ('crocodile', 'cloud', 2),
#  ('crocodile', 'kangaroo', 2),
#  ('crocodile', 'seal', 2),
#  ('cup', 'can', 2),
#  ('dinosaur', 'lizard', 2),
#  ('dinosaur', 'otter', 2),
#  ('flatfish', 'snake', 2),
#  ('flatfish', 'woman', 2),
#  ('forest', 'caterpillar', 2),
#  ('forest', 'crocodile', 2),
#  ('forest', 'lobster', 2),
#  ('forest', 'mountain', 2),
#  ('forest', 'mushroom', 2),
#  ('forest', 'pine_tree', 2),
#  ('forest', 'road', 2),
#  ('fox', 'leopard', 2),
#  ('fox', 'tiger', 2),
#  ('fox', 'wolf', 2),
#  ('girl', 'flatfish', 2),
#  ('hamster', 'rabbit', 2),
#  ('kangaroo', 'cattle', 2),
#  ('kangaroo', 'fox', 2),
#  ('kangaroo', 'rabbit', 2),
#  ('kangaroo', 'squirrel', 2),
#  ('keyboard', 'skyscraper', 2),
#  ('lamp', 'bottle', 2),
#  ('lamp', 'keyboard', 2),
#  ('lamp', 'television', 2),
#  ('lawn_mower', 'tractor', 2),
#  ('leopard', 'kangaroo', 2),
#  ('leopard', 'raccoon', 2),
#  ('leopard', 'squirrel', 2),
#  ('leopard', 'wolf', 2),
#  ('lion', 'beaver', 2),
#  ('lizard', 'bicycle', 2),
#  ('lizard', 'camel', 2),
#  ('lizard', 'dinosaur', 2),
#  ('lizard', 'leopard', 2),
#  ('lizard', 'seal', 2),
#  ('lizard', 'worm', 2),
#  ('lobster', 'beaver', 2),
#  ('lobster', 'crocodile', 2),
#  ('man', 'flatfish', 2),
#  ('maple_tree', 'pine_tree', 2),
#  ('motorcycle', 'lawn_mower', 2),
#  ('mouse', 'lobster', 2),
#  ('mouse', 'spider', 2),
#  ('mushroom', 'butterfly', 2),
#  ('mushroom', 'lamp', 2),
#  ('oak_tree', 'pine_tree', 2),
#  ('oak_tree', 'willow_tree', 2),
#  ('orchid', 'tulip', 2),
#  ('otter', 'chimpanzee', 2),
#  ('otter', 'crocodile', 2),
#  ('otter', 'dinosaur', 2),
#  ('otter', 'flatfish', 2),
#  ('otter', 'kangaroo', 2),
#  ('otter', 'possum', 2),
#  ('otter', 'squirrel', 2),
#  ('pear', 'bowl', 2),
#  ('pear', 'mushroom', 2),
#  ('pear', 'snail', 2),
#  ('pear', 'sweet_pepper', 2),
#  ('pickup_truck', 'bus', 2),
#  ('pickup_truck', 'streetcar', 2),
#  ('pine_tree', 'castle', 2),
#  ('pine_tree', 'forest', 2),
#  ('plain', 'forest', 2),
#  ('poppy', 'orchid', 2),
#  ('porcupine', 'fox', 2),
#  ('porcupine', 'raccoon', 2),
#  ('porcupine', 'willow_tree', 2),
#  ('possum', 'bear', 2),
#  ('possum', 'otter', 2),
#  ('possum', 'porcupine', 2),
#  ('rabbit', 'camel', 2),
#  ('rabbit', 'elephant', 2),
#  ('rabbit', 'fox', 2),
#  ('rabbit', 'mouse', 2),
#  ('rabbit', 'seal', 2),
#  ('rabbit', 'shrew', 2),
#  ('rabbit', 'snail', 2),
#  ('raccoon', 'elephant', 2),
#  ('raccoon', 'skunk', 2),
#  ('road', 'mountain', 2),
#  ('rocket', 'whale', 2),
#  ('sea', 'plain', 2),
#  ('seal', 'pine_tree', 2),
#  ('seal', 'porcupine', 2),
#  ('seal', 'turtle', 2),
#  ('shrew', 'possum', 2),
#  ('shrew', 'seal', 2),
#  ('snail', 'mouse', 2),
#  ('snail', 'mushroom', 2),
#  ('snake', 'caterpillar', 2),
#  ('snake', 'crab', 2),
#  ('spider', 'butterfly', 2),
#  ('spider', 'crab', 2),
#  ('spider', 'turtle', 2),
#  ('squirrel', 'beaver', 2),
#  ('squirrel', 'crocodile', 2),
#  ('squirrel', 'fox', 2),
#  ('squirrel', 'kangaroo', 2),
#  ('squirrel', 'mushroom', 2),
#  ('squirrel', 'seal', 2),
#  ('streetcar', 'bridge', 2),
#  ('streetcar', 'house', 2),
#  ('sunflower', 'tulip', 2),
#  ('sweet_pepper', 'apple', 2),
#  ('sweet_pepper', 'orange', 2),
#  ('sweet_pepper', 'pear', 2),
#  ('table', 'cup', 2),
#  ('table', 'lamp', 2),
#  ('tank', 'bus', 2),
#  ('tank', 'rocket', 2),
#  ('tank', 'telephone', 2),
#  ('telephone', 'can', 2),
#  ('telephone', 'television', 2),
#  ('television', 'lamp', 2),
#  ('television', 'man', 2),
#  ('television', 'telephone', 2),
#  ('television', 'wardrobe', 2),
#  ('tractor', 'pickup_truck', 2),
#  ('trout', 'aquarium_fish', 2),
#  ('trout', 'shrew', 2),
#  ('turtle', 'crab', 2),
#  ('turtle', 'ray', 2),
#  ('turtle', 'shark', 2),
#  ('turtle', 'shrew', 2),
#  ('wardrobe', 'television', 2),
#  ('whale', 'otter', 2),
#  ('whale', 'seal', 2),
#  ('willow_tree', 'palm_tree', 2),
#  ('wolf', 'crocodile', 2),
#  ('wolf', 'fox', 2),
#  ('wolf', 'possum', 2),
#  ('woman', 'chimpanzee', 2),
#  ('worm', 'lizard', 2)]

# %% [markdown]
# # Exercise 1: Train a DenseNet201 resizing images to 224x224

# %%
# Load data

# %%
# Initialize learner

# %%
# Find learning rate

# %%
# Set learning rate

# %%
# Train 1 epochs

# %%
# Save model

# %%
# Unfreeze conv layers

# %%
# Find learning rate

# %%
# Set learning rate

# %%
# Train 5 epochs

# %%
# Save model

# %%
# Mostrar muestras peor classificadas

# %%
# Show confusion matrix

# %%
# Show most confused classes
